# %%
import cv2
import numpy as np
import time
import json
import queue
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from ultralytics import YOLO

def load_yolo_model():
    model_path = "yolov8_aug.pt"
    model = YOLO(model_path)
    return model

def calculate_distance_models():
    with open("datasplit.json", 'r') as file:
        data = json.load(file)

    tw_x_values1 = np.array(data['tw_x_values1']).reshape(-1, 1)
    tw_y_values1 = np.array(data['tw_y_values1'])
    tw_x_values2 = np.array(data['tw_x_values2']).reshape(-1, 1)
    tw_y_values2 = np.array(data['tw_y_values2'])

    poly_features1 = PolynomialFeatures(degree=3)
    x_poly1 = poly_features1.fit_transform(tw_x_values1)
    model1 = LinearRegression()
    model1.fit(x_poly1, tw_y_values1)

    poly_features2 = PolynomialFeatures(degree=3)
    x_poly2 = poly_features2.fit_transform(tw_x_values2)
    model2 = LinearRegression()
    model2.fit(x_poly2, tw_y_values2)

    return model1, poly_features1, model2, poly_features2

def calculate_velocity(distance1, distance2, time_elapsed):
    velocity = (abs(distance2 - distance1)) / time_elapsed if time_elapsed > 0 else 0
    print(f"Calculated Velocity: {velocity:.2f} m/s")
    return velocity

def calculate_acceleration(velocity1, velocity2, time_elapsed):
    acceleration = (abs(velocity2 - velocity1)) / time_elapsed if time_elapsed > 0 else 0
    print(f"Calculated Acceleration: {acceleration:.2f} m/s²")
    return acceleration

def generate_random_points(center, radius=1, num_points=10):
    points = center + np.random.uniform(-radius, radius, (num_points, 2))
    print(f"Generated Points Around Center: {points}")
    return points

def determine_direction(prev_points, curr_points):
    dx = curr_points[:, 0] - prev_points[:, 0]
    dy = curr_points[:, 1] - prev_points[:, 1]

    directions = []
    for delta_x, delta_y in zip(dx, dy):
        if abs(delta_x) > abs(delta_y):
            if delta_x > 0:
                directions.append("Right")
            else:
                directions.append("Left")
        else:
            if delta_y > 0:
                directions.append("Down")
            else:
                directions.append("Up")

    direction = "Center" if len(set(directions)) > 1 else max(set(directions), key=directions.count)
    print(f"Determined Direction: {direction}")
    return direction

def process_frame(model, frame_queue, output_queue, stop_event):
    model1, poly_features1, model2, poly_features2 = calculate_distance_models()
    track_history = {}
    
    while not stop_event.is_set():
        if not frame_queue.empty():
            frame = frame_queue.get()
            results = model.track(frame, persist=True)
            output_queue.put((frame, results))

def track_and_analyze(model, camera_index=0, output_path="/home/lightray/Desktop/processed_video.avi", fps=40):
    cap = cv2.VideoCapture(camera_index)
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))
    
    track_history = {}
    velocity_history = {}
    acceleration_history = {}
    previous_times = {}
    previous_centers = {}
    threshold = 3  # Example threshold value
    
    while cap.isOpened():
        success, frame = cap.read()
        if not success:
            break
    
        results = model.track(frame, persist=True)
        if results and hasattr(results[0], 'boxes') and results[0].boxes:
            boxes = results[0].boxes

            if hasattr(boxes, 'xywh') and hasattr(boxes, 'id') and boxes.id is not None:
                track_ids = boxes.id.int().cpu().tolist()
                boxes_xywh = boxes.xywh.cpu().numpy()
                confidences = boxes.conf.cpu().numpy()
                class_names = [results[0].names[i] for i in boxes.cls.int().cpu().tolist()]

                for box, track_id, confidence, class_name in zip(boxes_xywh, track_ids, confidences, class_names):
                    x, y, w, h = box
                    center = np.array([x, y])
                    area = w * h

                    model1, poly_features1, model2, poly_features2 = calculate_distance_models()

                    if area > 46200:
                        x_poly1_pred = poly_features1.transform([[area]])
                        predicted_y = model1.predict(x_poly1_pred)
                    else:
                        x_poly2_pred = poly_features2.transform([[area]])
                        predicted_y = model2.predict(x_poly2_pred)

                    distance = predicted_y[0] if isinstance(predicted_y, np.ndarray) else predicted_y
                    print(f"Track ID: {track_id}, Class: {class_name}, Confidence: {confidence:.2f}, Distance: {distance:.2f}m")
                    if track_id not in track_history:
                        track_history[track_id] = []
                        velocity_history[track_id] = []
                        acceleration_history[track_id] = []
                        previous_times[track_id] = []
                        previous_centers[track_id] = center

                    track_history[track_id].append((x, y, w, h, distance))
                    previous_times[track_id].append(time.time())

                    if len(track_history[track_id]) >= 10 and len(previous_times[track_id]) >= 10:
                        prev_frame_data = track_history[track_id][-10]
                        prev_distance = prev_frame_data[4]
                        time_elapsed = previous_times[track_id][-1] - previous_times[track_id][-10]

                        velocity = calculate_velocity(prev_distance, distance, time_elapsed)
                        velocity_history[track_id].append(velocity)

                        if len(velocity_history[track_id]) >= 2:
                            prev_velocity = velocity_history[track_id][-2]
                            acceleration = calculate_acceleration(prev_velocity, velocity, time_elapsed)
                        else:
                            acceleration = 0
                        acceleration_history[track_id].append(acceleration)

                        prev_points = generate_random_points(previous_centers[track_id])
                        curr_points = generate_random_points(center)
                        direction = determine_direction(prev_points, curr_points)
                        previous_centers[track_id] = center

                        # Calculate the product of distance and velocity
                        time_to_collide = distance / velocity
                        
                        # Choose color based on threshold
                        color = (0, 0, 255) if time_to_collide < threshold else (255, 255, 255)  # Red if above threshold, white otherwise

                        text_y = int(y - h/2 - 110)
                        cv2.putText(frame, f"Track ID: {track_id}", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
                        text_y += 15
                        cv2.putText(frame, f"Confidence: {confidence:.2f}", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
                        text_y += 15
                        cv2.putText(frame, f"Class: {class_name}", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
                        text_y += 15
                        cv2.putText(frame, f"Distance: {distance:.2f}m", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
                        text_y += 15
                        cv2.putText(frame, f"Elapsed Time: {time_elapsed:.2f}s", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
                        text_y += 15
                        cv2.putText(frame, f"Velocity: {velocity:.2f}m/s", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
                        text_y += 15
                        cv2.putText(frame, f"Acceleration: {acceleration:.2f}m/s²", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
                        text_y += 15
                        cv2.putText(frame, f"Direction: {direction}", (int(x - w/2), text_y),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

                        cv2.rectangle(frame, (int(x - w/2), int(y - h/2)),
                                      (int(x + w/2), int(y + h/2)), (0, 255, 0), 2)
        out.write(frame)
        cv2.imshow("YOLO Real-Time Detection", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()

    plot_combined_velocity_acceleration(velocity_history, acceleration_history)

def plot_combined_velocity_acceleration(velocity_history, acceleration_history):
    plt.figure(figsize=(14, 10))

    plt.subplot(2, 1, 1)
    for track_id, velocities in velocity_history.items():
        plt.plot(velocities, label=f'Vehicle {track_id}')
    plt.xlabel('Frame')
    plt.ylabel('Velocity (m/s)')
    plt.title('Velocity of All Vehicles')
    plt.legend()
    plt.grid()

    plt.subplot(2, 1, 2)
    for track_id, accelerations in acceleration_history.items():
        plt.plot(accelerations, label=f'Vehicle {track_id}')
    plt.xlabel('Frame')
    plt.ylabel('Acceleration (m/s²)')
    plt.title('Acceleration of All Vehicles')
    plt.legend()
    plt.grid()

    plt.tight_layout()
    plt.show()

model = load_yolo_model()
track_and_analyze(model)
# Out:
# 0: 480x640 1 RICK, 1 TW, 117.5ms
# Speed: 5.7ms preprocess, 117.5ms inference, 148.9ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.51m
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.55m
#
# 0: 480x640 1 RICK, 1 TW, 52.9ms
# Speed: 3.6ms preprocess, 52.9ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.95, Distance: 2.51m
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.48m
#
# 0: 480x640 1 RICK, 1 TW, 60.6ms
# Speed: 3.3ms preprocess, 60.6ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.51m
# Track ID: 2, Class: RICK, Confidence: 0.93, Distance: 1.46m
#
# 0: 480x640 1 RICK, 1 TW, 34.2ms
# Speed: 3.2ms preprocess, 34.2ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.95, Distance: 2.52m
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.46m
#
# 0: 480x640 1 RICK, 1 TW, 36.5ms
# Speed: 2.6ms preprocess, 36.5ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.95, Distance: 2.51m
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.50m
#
# 0: 480x640 1 RICK, 1 TW, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.52m
# Track ID: 2, Class: RICK, Confidence: 0.93, Distance: 1.58m
#
# 0: 480x640 1 RICK, 1 TW, 45.7ms
# Speed: 2.9ms preprocess, 45.7ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.51m
# Track ID: 2, Class: RICK, Confidence: 0.94, Distance: 1.58m
#
# 0: 480x640 1 RICK, 1 TW, 31.3ms
# Speed: 2.6ms preprocess, 31.3ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.51m
# Track ID: 2, Class: RICK, Confidence: 0.94, Distance: 1.55m
#
# 0: 480x640 1 RICK, 1 TW, 28.0ms
# Speed: 2.2ms preprocess, 28.0ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.52m
# Track ID: 2, Class: RICK, Confidence: 0.93, Distance: 1.55m
#
# 0: 480x640 1 RICK, 1 TW, 31.6ms
# Speed: 2.2ms preprocess, 31.6ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.51m
# Calculated Velocity: 0.00 m/s
# Generated Points Around Center: [[     564.57      349.26]
#  [     564.62      349.31]
#  [     565.32      347.96]
#  [     564.21      348.38]
#  [     564.31      349.74]
#  [     564.86      349.07]
#  [     564.68      347.95]
#  [     564.48       348.7]
#  [     563.83         349]
#  [     565.23      347.89]]
# Generated Points Around Center: [[     530.89      345.82]
#  [     531.12      347.14]
#  [     530.66      346.07]
#  [     531.65      346.98]
#  [     531.04      347.75]
#  [     531.51      345.87]
#  [     531.11      346.61]
#  [     531.02      346.19]
#  [     530.41      346.38]
#  [     532.03      346.48]]
# Determined Direction: Left
# Track ID: 2, Class: RICK, Confidence: 0.93, Distance: 1.56m
# Calculated Velocity: 0.01 m/s
# Generated Points Around Center: [[     325.11      274.19]
#  [     324.69       275.7]
#  [     324.88      275.96]
#  [     324.77      276.01]
#  [     324.12         275]
#  [     323.86      275.77]
#  [     324.73      275.78]
#  [     324.11      274.79]
#  [     325.59      274.37]
#  [     324.21      274.81]]
# Generated Points Around Center: [[     293.97      269.94]
#  [     295.07      269.54]
#  [     293.92      268.65]
#  [     294.04      269.77]
#  [     294.42      268.46]
#  [     294.67      268.41]
#  [     294.18       269.7]
#  [     294.03      268.71]
#  [     294.92       268.4]
#  [     294.41      269.44]]
# Determined Direction: Left
#
# 0: 480x640 1 RICK, 1 TW, 19.3ms
# Speed: 2.1ms preprocess, 19.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.95, Distance: 2.54m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     531.13      346.28]
#  [     530.72      347.58]
#  [      532.1       346.7]
#  [     531.51       346.7]
#  [     530.44      346.73]
#  [     530.25      347.32]
#  [     531.67       345.8]
#  [     530.68      347.73]
#  [     531.77      345.88]
#  [     530.98       347.7]]
# Generated Points Around Center: [[      524.9      348.35]
#  [     524.19      349.32]
#  [     525.53      348.11]
#  [     525.43      347.84]
#  [     524.36      348.94]
#  [      524.8       349.1]
#  [     525.05      348.51]
#  [      524.2      349.45]
#  [     524.13      348.86]
#  [      525.4      347.83]]
# Determined Direction: Left
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.57m
# Calculated Velocity: 0.08 m/s
# Calculated Acceleration: 0.06 m/s²
# Generated Points Around Center: [[     294.76      269.42]
#  [     293.92      268.53]
#  [     294.17      268.67]
#  [     295.21      268.48]
#  [     294.11      268.84]
#  [     294.42      268.84]
#  [     295.63      269.07]
#  [      294.1      269.71]
#  [     293.95       268.6]
#  [     295.39      269.38]]
# Generated Points Around Center: [[     289.99      270.68]
#  [     289.22      271.59]
#  [     290.24      270.88]
#  [     290.04      269.98]
#  [      289.2      270.29]
#  [     289.35      271.43]
#  [     289.22       269.9]
#  [     289.33      270.11]
#  [     289.37      270.31]
#  [     289.14       271.3]]
# Determined Direction: Left
#
# 0: 480x640 1 RICK, 1 TW, 23.4ms
# Speed: 2.3ms preprocess, 23.4ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.54m
# Calculated Velocity: 0.03 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[      523.9      349.44]
#  [      525.3      347.78]
#  [     524.35       349.7]
#  [     523.81      347.92]
#  [     523.84      349.43]
#  [      524.1      349.03]
#  [     524.64      348.28]
#  [     524.82      349.51]
#  [     524.91       348.9]
#  [     525.17       348.9]]
# Generated Points Around Center: [[     521.02      347.79]
#  [     520.61      348.73]
#  [     521.02      348.33]
#  [     520.89      348.81]
#  [     521.78      347.39]
#  [     520.24      348.46]
#  [     521.16      348.71]
#  [     521.77       347.4]
#  [     521.52      348.84]
#  [     521.46       347.3]]
# Determined Direction: Left
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.58m
# Calculated Velocity: 0.12 m/s
# Calculated Acceleration: 0.04 m/s²
# Generated Points Around Center: [[      289.2         270]
#  [     289.18      270.72]
#  [      288.9      271.06]
#  [     290.11      271.39]
#  [     288.39      270.29]
#  [     289.64      271.61]
#  [     288.72      270.36]
#  [     288.45      271.24]
#  [     289.36      270.28]
#  [     288.95      270.06]]
# Generated Points Around Center: [[      286.4      268.97]
#  [     287.94      270.02]
#  [     287.83      269.18]
#  [     286.76      268.95]
#  [     287.18      268.42]
#  [     287.25       269.8]
#  [     287.34      269.83]
#  [     286.58      269.26]
#  [      287.3      269.71]
#  [     288.16      269.53]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 24.2ms
# Speed: 2.2ms preprocess, 24.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.95, Distance: 2.55m
# Calculated Velocity: 0.03 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     521.61      347.33]
#  [     521.15         347]
#  [     520.36      348.09]
#  [     520.27      348.76]
#  [     519.95      347.75]
#  [     520.84      348.28]
#  [      520.8      348.39]
#  [     521.73      348.39]
#  [     521.32      348.15]
#  [     520.19      347.75]]
# Generated Points Around Center: [[     523.45      344.93]
#  [     522.74       344.3]
#  [     522.84      344.42]
#  [      522.3      344.51]
#  [     522.61      345.91]
#  [      523.2      345.61]
#  [     523.28      346.06]
#  [     523.01      344.73]
#  [     522.95      344.95]
#  [     522.38       346.1]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.58m
# Calculated Velocity: 0.12 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     288.22      268.73]
#  [     287.66      268.57]
#  [     287.49      268.67]
#  [     287.54      268.57]
#  [     287.25       268.9]
#  [      286.9      269.13]
#  [     286.72      268.82]
#  [     287.49      269.52]
#  [     288.23      269.11]
#  [      286.5       270.2]]
# Generated Points Around Center: [[     288.44      267.59]
#  [     288.26      267.01]
#  [     287.31      267.67]
#  [     289.22      268.06]
#  [     287.95      267.02]
#  [     288.97      266.82]
#  [     289.17      266.88]
#  [     289.29      268.42]
#  [     288.54      267.14]
#  [     289.24      267.43]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 23.3ms
# Speed: 4.1ms preprocess, 23.3ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.95, Distance: 2.55m
# Calculated Velocity: 0.04 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     522.41      344.88]
#  [     522.17      345.71]
#  [      522.8         346]
#  [     522.98      344.64]
#  [     522.83      346.13]
#  [     522.66      344.38]
#  [      523.4      345.77]
#  [     522.79      345.04]
#  [     522.04      344.81]
#  [     522.54      345.44]]
# Generated Points Around Center: [[     523.28      341.88]
#  [     522.39      341.75]
#  [     522.19      342.11]
#  [     522.69       341.3]
#  [     521.89      342.79]
#  [     523.31      341.72]
#  [     522.77      341.51]
#  [     522.99      341.67]
#  [     522.34      342.06]
#  [     522.18      342.74]]
# Determined Direction: Up
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.60m
# Calculated Velocity: 0.10 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     288.49      266.79]
#  [     288.56      268.33]
#  [     287.51      267.17]
#  [     288.81      267.67]
#  [     288.18      266.64]
#  [     288.67       267.5]
#  [     287.84      266.94]
#  [     288.03      268.24]
#  [     288.29      268.11]
#  [     288.99      268.11]]
# Generated Points Around Center: [[     288.83      263.98]
#  [     287.66      263.79]
#  [     288.12      262.97]
#  [      288.8      263.18]
#  [     288.44      262.96]
#  [     288.42      263.88]
#  [     288.91      263.62]
#  [     287.99      262.68]
#  [     288.64      264.67]
#  [     288.16      263.42]]
# Determined Direction: Up
#
# 0: 480x640 1 RICK, 1 TW, 26.6ms
# Speed: 2.4ms preprocess, 26.6ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.54m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     523.38      342.63]
#  [     522.19       341.8]
#  [     523.08      341.03]
#  [     522.23      341.46]
#  [     522.72      341.86]
#  [     523.39      342.25]
#  [     523.56      342.47]
#  [     523.09      342.43]
#  [     523.26      342.33]
#  [      522.8      341.25]]
# Generated Points Around Center: [[     520.15      343.98]
#  [     519.91      344.47]
#  [     519.34      345.31]
#  [     518.47      345.42]
#  [     519.31      344.14]
#  [     519.63      345.48]
#  [     519.88      344.64]
#  [     518.95      344.26]
#  [     518.67      343.96]
#  [     518.72      345.59]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.60m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.08 m/s²
# Generated Points Around Center: [[     287.11      264.13]
#  [     288.66      263.31]
#  [     288.77      263.47]
#  [     288.74      263.31]
#  [     288.21      263.25]
#  [     288.92      264.25]
#  [     287.54      264.53]
#  [     288.74      263.21]
#  [     288.51      263.54]
#  [     288.05       263.6]]
# Generated Points Around Center: [[     285.83       266.6]
#  [     285.89      265.81]
#  [     285.85      266.69]
#  [     285.86      265.83]
#  [     285.52      266.33]
#  [      286.6      265.88]
#  [     286.51      266.43]
#  [     285.67      265.82]
#  [     286.14      265.79]
#  [     285.38       266.4]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.54m
# Calculated Velocity: 0.04 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     520.01      345.57]
#  [     518.81      344.72]
#  [     520.28      345.16]
#  [     518.65      344.22]
#  [     519.28      345.35]
#  [     519.15      345.41]
#  [     520.24      345.37]
#  [     519.68      343.78]
#  [     518.36      344.27]
#  [     518.62      345.34]]
# Generated Points Around Center: [[     515.78      340.81]
#  [     515.66      340.35]
#  [     516.98      341.81]
#  [     516.55      341.43]
#  [        516      341.27]
#  [     517.35      341.12]
#  [     516.08      341.63]
#  [     515.91      341.01]
#  [     516.22      341.63]
#  [     515.81      341.78]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.58m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     285.58      266.81]
#  [      285.7      266.52]
#  [      285.8      267.17]
#  [     285.14      266.55]
#  [     284.73      267.06]
#  [     286.42      266.89]
#  [     286.37      267.27]
#  [        285      267.23]
#  [     285.16      266.27]
#  [     285.89      266.31]]
# Generated Points Around Center: [[     280.58      270.63]
#  [     280.38      270.98]
#  [     280.46      271.06]
#  [     279.22      270.49]
#  [     280.07      272.11]
#  [     279.64      271.56]
#  [     279.61      270.55]
#  [        281      270.39]
#  [     280.64      271.81]
#  [     280.11      270.42]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 20.1ms
# Speed: 4.3ms preprocess, 20.1ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.92, Distance: 2.54m
# Calculated Velocity: 0.03 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[      516.6      341.38]
#  [     516.77      341.43]
#  [     516.07      340.48]
#  [      516.6      341.74]
#  [     516.89      341.92]
#  [     517.44      341.47]
#  [     516.99      340.46]
#  [     515.93      341.87]
#  [     517.35      342.17]
#  [     517.48       341.7]]
# Generated Points Around Center: [[     507.03      333.65]
#  [     507.29      333.73]
#  [     506.21      334.97]
#  [      506.3      334.58]
#  [     506.18       334.7]
#  [     506.75      335.17]
#  [     506.46      334.55]
#  [      507.4      335.34]
#  [     507.54      334.09]
#  [     507.18       334.3]]
# Determined Direction: Left
# Track ID: 2, Class: RICK, Confidence: 0.93, Distance: 1.61m
# Calculated Velocity: 0.06 m/s
# Calculated Acceleration: 0.06 m/s²
# Generated Points Around Center: [[     280.32      270.23]
#  [     280.14      271.49]
#  [     280.21      271.76]
#  [     279.69      270.69]
#  [      279.7      270.45]
#  [     279.44      270.62]
#  [     279.66      270.91]
#  [     280.92      270.43]
#  [     280.61       271.4]
#  [      281.1         271]]
# Generated Points Around Center: [[     266.48      270.92]
#  [     265.59      269.25]
#  [     266.61      269.35]
#  [     266.63      269.47]
#  [     266.02      269.52]
#  [     265.05      270.73]
#  [     265.88      269.25]
#  [     265.81      270.81]
#  [     266.85      270.26]
#  [     265.22      270.81]]
# Determined Direction: Left
#
# 0: 480x640 1 RICK, 1 TW, 22.5ms
# Speed: 2.5ms preprocess, 22.5ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.52m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     506.22      334.07]
#  [     507.95      333.72]
#  [     506.45      334.83]
#  [     506.46         334]
#  [     507.89      335.36]
#  [     507.01      333.57]
#  [     506.26      333.93]
#  [        507      333.74]
#  [     507.44      334.95]
#  [     506.41      333.76]]
# Generated Points Around Center: [[     496.82      325.97]
#  [      498.4      326.49]
#  [     496.66      326.11]
#  [     497.86      325.17]
#  [     497.87      325.81]
#  [     497.41      325.44]
#  [     497.75      325.63]
#  [     496.65      325.19]
#  [     497.83         325]
#  [     497.72      326.28]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.60m
# Calculated Velocity: 0.05 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     265.55      271.02]
#  [     265.72      269.91]
#  [      265.5      269.69]
#  [     266.43      270.17]
#  [      265.1      270.94]
#  [     265.54      269.48]
#  [     265.68         271]
#  [     266.39      270.12]
#  [     265.02      271.02]
#  [     266.53      270.12]]
# Generated Points Around Center: [[     252.83      261.62]
#  [     252.89      261.63]
#  [     252.46      261.19]
#  [     253.67      261.86]
#  [     253.94      261.08]
#  [     253.24      261.31]
#  [     252.87      262.71]
#  [     253.03      262.74]
#  [     253.01      262.43]
#  [     253.86      260.86]]
# Determined Direction: Left
#
# 0: 480x640 1 RICK, 1 TW, 36.8ms
# Speed: 2.6ms preprocess, 36.8ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.52m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     497.25      326.21]
#  [     496.67      325.02]
#  [     497.03      325.32]
#  [     496.74      326.62]
#  [     496.96      326.43]
#  [     497.55      324.79]
#  [     498.52      325.83]
#  [     498.31      326.53]
#  [     496.89      326.27]
#  [     497.67       325.2]]
# Generated Points Around Center: [[     497.06      321.85]
#  [     496.93      320.03]
#  [     497.88      321.04]
#  [     496.98      321.88]
#  [     496.17       320.8]
#  [     495.96      321.75]
#  [     497.85       320.1]
#  [     497.59      321.82]
#  [     496.74      320.54]
#  [      497.5      320.91]]
# Determined Direction: Up
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.59m
# Calculated Velocity: 0.03 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     254.27      261.35]
#  [      252.8      262.51]
#  [      254.3      261.14]
#  [     253.49      261.79]
#  [      253.9      262.37]
#  [     252.37      262.23]
#  [     252.33      261.75]
#  [     253.17       261.1]
#  [     254.26      262.18]
#  [     252.87      261.43]]
# Generated Points Around Center: [[     248.29      254.82]
#  [     247.84      254.27]
#  [     249.23      254.98]
#  [     249.26      254.32]
#  [     248.36      253.75]
#  [     248.96      253.99]
#  [     249.68      254.42]
#  [     249.65      255.01]
#  [     249.23      253.97]
#  [     248.13      253.66]]
# Determined Direction: Up
#
# 0: 480x640 1 RICK, 1 TW, 20.1ms
# Speed: 4.0ms preprocess, 20.1ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.51m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[      496.2      320.67]
#  [     497.34      321.95]
#  [     496.46      321.95]
#  [     497.46      321.09]
#  [     496.91      320.36]
#  [     497.49       320.6]
#  [     497.67      321.47]
#  [     497.04      321.42]
#  [     496.69       320.1]
#  [     496.33       320.8]]
# Generated Points Around Center: [[     500.57       320.6]
#  [     499.11      321.22]
#  [     499.87      320.05]
#  [     500.55      320.36]
#  [     500.16      319.62]
#  [     499.65      319.88]
#  [     499.65      319.53]
#  [     499.84      320.73]
#  [     499.01      320.48]
#  [     500.23      320.22]]
# Determined Direction: Right
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.61m
# Calculated Velocity: 0.04 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     248.98      253.47]
#  [     249.02      255.15]
#  [     249.14      253.59]
#  [     249.74       253.8]
#  [     247.84       255.1]
#  [     248.01      254.44]
#  [     248.89       254.1]
#  [     248.82      255.04]
#  [      248.9      254.61]
#  [     247.99      254.96]]
# Generated Points Around Center: [[     253.72      252.92]
#  [     253.69      253.74]
#  [     253.68      252.78]
#  [     252.33      254.55]
#  [     253.88      253.03]
#  [     253.98      252.84]
#  [      253.2      254.45]
#  [     252.14      253.61]
#  [     252.89      253.88]
#  [     253.31      253.28]]
# Determined Direction: Right
#
# 0: 480x640 1 RICK, 1 TW, 25.8ms
# Speed: 2.2ms preprocess, 25.8ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.53m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     500.53      320.31]
#  [      499.9      320.13]
#  [      499.8      319.53]
#  [      499.3      320.98]
#  [     500.43      320.91]
#  [     500.12      321.25]
#  [     498.88      321.02]
#  [     499.21      319.51]
#  [     500.75      320.28]
#  [     500.45       320.4]]
# Generated Points Around Center: [[     501.05      319.68]
#  [     501.56      319.26]
#  [     501.85      319.02]
#  [     501.25      319.99]
#  [     501.99      320.49]
#  [     501.69      318.79]
#  [     501.17      320.43]
#  [     500.92       320.2]
#  [      501.9      319.99]
#  [     501.82      320.52]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.62m
# Calculated Velocity: 0.05 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     252.33      253.44]
#  [     253.38      254.38]
#  [     253.01      253.29]
#  [     252.74      252.86]
#  [     252.45      253.51]
#  [     253.39      253.77]
#  [     252.33      253.92]
#  [     252.48      252.73]
#  [     253.43      253.17]
#  [     252.09      254.37]]
# Generated Points Around Center: [[      255.2      251.61]
#  [     255.47      252.01]
#  [     256.27      251.15]
#  [     256.31      252.44]
#  [      255.9      251.73]
#  [     256.24      251.83]
#  [     256.04      251.23]
#  [     255.99      250.98]
#  [     255.17      251.08]
#  [     256.76      252.65]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 31.5ms
# Speed: 2.2ms preprocess, 31.5ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.52m
# Calculated Velocity: 0.03 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     500.92      319.02]
#  [     502.46      319.47]
#  [     501.54      319.32]
#  [     501.78      319.69]
#  [      501.5      320.01]
#  [     502.37      319.64]
#  [     501.29      320.41]
#  [     502.14      319.39]
#  [     500.99      320.72]
#  [     501.32      320.58]]
# Generated Points Around Center: [[     499.44      318.53]
#  [      498.7      319.22]
#  [     499.48      319.27]
#  [     499.35      318.71]
#  [     499.13       318.4]
#  [     499.85         319]
#  [     499.59      319.39]
#  [     499.47      318.81]
#  [     499.63      317.92]
#  [     500.48      318.45]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.61m
# Calculated Velocity: 0.04 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[      256.4      251.14]
#  [     256.73      252.33]
#  [     255.68       252.4]
#  [     255.83      252.63]
#  [     256.56      252.69]
#  [     256.57      252.49]
#  [     255.49      251.38]
#  [     256.62         251]
#  [     256.61      251.73]
#  [     255.76      251.13]]
# Generated Points Around Center: [[     253.99      249.61]
#  [     253.78      249.68]
#  [     253.39       250.2]
#  [     252.95      248.96]
#  [     254.11      248.97]
#  [     254.14      250.49]
#  [     254.02      249.96]
#  [     253.44      250.82]
#  [     253.99      249.15]
#  [     252.44      249.84]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 25.5ms
# Speed: 2.2ms preprocess, 25.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.50m
# Calculated Velocity: 0.05 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     499.92      318.62]
#  [     499.49      318.68]
#  [     499.83      318.98]
#  [     499.73      318.15]
#  [     500.35      319.34]
#  [     499.91      319.29]
#  [     499.38      319.03]
#  [     498.66      318.83]
#  [     499.74      317.76]
#  [     500.13      318.92]]
# Generated Points Around Center: [[      497.3      321.85]
#  [     496.94      321.38]
#  [      496.9      321.59]
#  [     496.28      320.89]
#  [     497.18      322.05]
#  [     497.04      321.38]
#  [     496.82         321]
#  [     496.76      320.53]
#  [     496.34      321.34]
#  [     497.48      320.53]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.61m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     253.72      248.98]
#  [     252.93      249.38]
#  [     253.84      250.79]
#  [     253.06      250.44]
#  [     252.54       250.6]
#  [     253.34       249.6]
#  [     253.39      250.66]
#  [     252.58      250.49]
#  [     252.56      250.37]
#  [     254.07      250.53]]
# Generated Points Around Center: [[     249.44      250.89]
#  [     249.15      251.33]
#  [     249.09      252.56]
#  [     250.37      251.79]
#  [     249.48      251.94]
#  [     249.86      251.07]
#  [      250.5      251.52]
#  [     249.94      250.88]
#  [     250.45       251.8]
#  [     250.61      252.39]]
# Determined Direction: Left
#
# 0: 480x640 1 RICK, 1 TW, 27.2ms
# Speed: 5.2ms preprocess, 27.2ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.51m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     496.82      321.95]
#  [     496.03      322.05]
#  [     496.27      322.24]
#  [     496.71      321.34]
#  [     497.25      320.71]
#  [     496.46      321.11]
#  [     497.13      321.73]
#  [     496.84      321.56]
#  [     496.79      321.64]
#  [     495.71      321.71]]
# Generated Points Around Center: [[     495.43       318.1]
#  [     494.89      318.75]
#  [     494.58      317.57]
#  [     495.12      317.65]
#  [     494.43      318.45]
#  [     495.29      319.39]
#  [     495.57      318.19]
#  [     494.52      318.24]
#  [     495.86      318.44]
#  [     495.12      318.02]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.62m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     249.63      251.79]
#  [     250.49      252.24]
#  [     249.55         252]
#  [     250.77      251.41]
#  [     250.88       251.1]
#  [     250.39      251.96]
#  [      249.2      251.97]
#  [     250.08      251.07]
#  [      249.4       252.4]
#  [     249.68      252.25]]
# Generated Points Around Center: [[     248.76      248.31]
#  [     248.07      249.41]
#  [     248.36      248.08]
#  [     248.68      248.71]
#  [     247.57      248.17]
#  [     248.43      248.85]
#  [     248.49      247.59]
#  [      248.5      247.98]
#  [     248.93         248]
#  [     247.73       248.9]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.52m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     496.14       319.5]
#  [     496.09       319.2]
#  [     495.75      318.67]
#  [     494.48      318.54]
#  [     494.39      318.76]
#  [     495.85      318.61]
#  [     494.57       319.5]
#  [     494.51      318.24]
#  [     494.86      318.96]
#  [      495.8      318.25]]
# Generated Points Around Center: [[     495.86      317.19]
#  [      497.6      317.21]
#  [     497.07      317.01]
#  [     496.82      315.75]
#  [     496.98      316.18]
#  [     496.07      317.42]
#  [     497.59      317.15]
#  [     496.54      317.37]
#  [     496.07      317.55]
#  [     495.89      315.62]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.61m
# Calculated Velocity: 0.03 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     247.44      249.13]
#  [     247.67      248.25]
#  [     248.23      248.52]
#  [      247.2         248]
#  [     247.19      248.65]
#  [     248.61      248.94]
#  [     247.26         248]
#  [     247.59      248.66]
#  [     248.32      248.49]
#  [     248.03      248.26]]
# Generated Points Around Center: [[     248.12      246.73]
#  [     249.07      248.61]
#  [     248.85      248.08]
#  [     249.57      247.03]
#  [     248.48      248.09]
#  [     247.97      247.17]
#  [     249.35       248.2]
#  [      248.7      247.98]
#  [     248.38      248.01]
#  [     247.98      248.07]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 31.9ms
# Speed: 2.5ms preprocess, 31.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.51m
# Calculated Velocity: 0.03 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     496.94      316.93]
#  [     496.66      315.83]
#  [     496.32       317.5]
#  [     497.72      317.36]
#  [     497.66      316.29]
#  [     497.07      316.38]
#  [     497.55      317.21]
#  [     497.67      316.67]
#  [     495.91      315.59]
#  [     496.26      316.96]]
# Generated Points Around Center: [[     497.33      317.52]
#  [     497.21      318.83]
#  [     496.64       318.7]
#  [     497.13      319.18]
#  [     497.17      319.25]
#  [     497.33      318.79]
#  [     497.03      318.35]
#  [     497.01       318.1]
#  [     496.03      318.57]
#  [     497.17       319.2]]
# Determined Direction: Down
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.62m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     248.31      246.76]
#  [     249.08      247.46]
#  [     248.56      247.17]
#  [     249.11      247.58]
#  [     248.92      248.62]
#  [     247.81      248.49]
#  [     248.61      248.41]
#  [      247.6      248.25]
#  [     248.08      247.32]
#  [     248.55      248.11]]
# Generated Points Around Center: [[     251.24      249.58]
#  [     252.43      249.95]
#  [     250.49      250.76]
#  [     252.37       249.9]
#  [     250.93       248.8]
#  [     251.26      250.56]
#  [     251.69      249.48]
#  [     250.51      249.71]
#  [     252.33      250.75]
#  [     251.89      249.37]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 27.9ms
# Speed: 2.7ms preprocess, 27.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.52m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     497.81      318.47]
#  [     496.78      319.34]
#  [     496.64      317.47]
#  [     496.82      317.67]
#  [     497.13      317.53]
#  [      497.1      319.18]
#  [     496.67      317.73]
#  [     497.73      317.82]
#  [     497.46      318.09]
#  [     497.82      318.23]]
# Generated Points Around Center: [[     496.98      319.72]
#  [      496.4      319.02]
#  [      496.5      318.09]
#  [     496.98      318.79]
#  [     496.36      318.55]
#  [     496.22      319.64]
#  [     497.99      318.41]
#  [     497.45      319.57]
#  [     497.77      318.88]
#  [     497.66      319.43]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.62m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     251.76      249.84]
#  [     251.27      249.36]
#  [     251.61      249.91]
#  [        252      249.34]
#  [     250.62      250.63]
#  [     252.35      249.17]
#  [     250.72      250.11]
#  [     251.13      248.82]
#  [     251.03      249.94]
#  [     250.88      250.13]]
# Generated Points Around Center: [[     251.34      247.83]
#  [      250.7      247.82]
#  [     251.01      248.81]
#  [     250.29      249.33]
#  [     251.64      249.34]
#  [     250.78      248.87]
#  [     250.16      248.34]
#  [      251.6      249.65]
#  [     250.74         249]
#  [     251.29      248.14]]
# Determined Direction: Center
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 20.4ms
# Speed: 2.7ms preprocess, 20.4ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.52m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     497.78      319.16]
#  [      497.1      318.16]
#  [      497.9       319.4]
#  [     497.74       318.7]
#  [      497.4      318.14]
#  [     498.11      319.27]
#  [     496.81      318.25]
#  [     497.36      318.96]
#  [     496.85      319.81]
#  [     496.61      318.99]]
# Generated Points Around Center: [[      497.4      317.89]
#  [      497.6      318.35]
#  [     497.77      317.56]
#  [     498.29      317.49]
#  [     498.07      317.15]
#  [     498.14      317.65]
#  [     497.88       317.2]
#  [     496.47      316.38]
#  [     498.09      317.21]
#  [     497.86      318.21]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.61m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     250.38      248.24]
#  [     250.05       249.2]
#  [     250.41      249.49]
#  [     250.75      249.21]
#  [     250.23      247.81]
#  [     250.95      249.42]
#  [     250.01      248.07]
#  [      251.1       248.4]
#  [     251.81      248.96]
#  [     251.68      248.83]]
# Generated Points Around Center: [[     252.76       249.9]
#  [     252.39      248.47]
#  [     251.36      249.24]
#  [      252.6      249.87]
#  [     251.75      248.98]
#  [     251.91      248.36]
#  [     251.55      248.99]
#  [     252.69      247.93]
#  [     252.77      249.86]
#  [     251.98      248.36]]
# Determined Direction: Center
# Track ID: 8, Class: LMV, Confidence: 0.40, Distance: 6.34m
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 27.4ms
# Speed: 2.4ms preprocess, 27.4ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.50m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     496.44      318.24]
#  [     497.36      318.33]
#  [     497.62      317.41]
#  [     497.18       316.6]
#  [     497.78      316.88]
#  [      497.1      317.34]
#  [     497.91      317.71]
#  [     497.48      318.13]
#  [     496.49      316.46]
#  [     498.01      317.79]]
# Generated Points Around Center: [[     498.02      319.72]
#  [     496.37      318.78]
#  [     497.63      318.34]
#  [     497.24      320.06]
#  [     497.71      320.08]
#  [     497.62       319.1]
#  [     496.34      319.97]
#  [     496.43      319.48]
#  [     497.77      319.65]
#  [     498.08      319.09]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.61m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     252.79      248.08]
#  [     252.06         249]
#  [      251.3      248.67]
#  [     253.02      249.67]
#  [     251.99      248.48]
#  [      251.6      248.59]
#  [     251.73      248.44]
#  [      252.3      249.38]
#  [     251.22      249.34]
#  [     253.06       249.1]]
# Generated Points Around Center: [[     252.29      250.83]
#  [     252.61      251.33]
#  [        252      251.02]
#  [      252.5      250.88]
#  [     251.57      250.28]
#  [      251.7      251.82]
#  [      252.5      250.52]
#  [     251.87      251.52]
#  [     250.92      250.06]
#  [     252.01      251.05]]
# Determined Direction: Down
# Track ID: 8, Class: LMV, Confidence: 0.15, Distance: 6.37m
#
# 0: 480x640 1 RICK, 1 TW, 27.0ms
# Speed: 2.1ms preprocess, 27.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.95, Distance: 2.53m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[      497.1      318.42]
#  [     496.85       319.9]
#  [     497.61      318.88]
#  [     496.79      318.51]
#  [     496.37      320.11]
#  [     496.37      319.59]
#  [     497.98      318.35]
#  [     496.84      319.51]
#  [     496.67      318.86]
#  [     497.17      319.85]]
# Generated Points Around Center: [[     492.16       321.7]
#  [     492.02      321.84]
#  [     492.42      321.46]
#  [     491.84      320.72]
#  [     493.08      320.84]
#  [     491.29      321.02]
#  [     491.44      321.54]
#  [     491.77       320.8]
#  [      492.7      320.79]
#  [     491.85      321.67]]
# Determined Direction: Left
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.60m
# Calculated Velocity: 0.02 m/s
# Calculated Acceleration: 0.02 m/s²
# Generated Points Around Center: [[     252.25      251.19]
#  [     252.28      250.74]
#  [     251.97       251.2]
#  [     250.84      250.33]
#  [     252.61      249.98]
#  [     252.54      251.31]
#  [        252      250.12]
#  [     251.25      250.44]
#  [     251.27      251.51]
#  [     252.58       250.5]]
# Generated Points Around Center: [[     248.22      252.73]
#  [      247.2      252.49]
#  [     248.51      252.97]
#  [     247.75      252.48]
#  [      248.8      252.79]
#  [     248.13      253.15]
#  [     248.83      253.43]
#  [     247.96      252.85]
#  [      248.4      252.34]
#  [     248.56      252.02]]
# Determined Direction: Center
#
# 0: 480x640 1 RICK, 1 TW, 30.3ms
# Speed: 2.6ms preprocess, 30.3ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.53m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     492.08      322.13]
#  [     492.13      320.72]
#  [     492.38      320.61]
#  [      492.9      321.32]
#  [     492.49      320.93]
#  [     492.94      322.19]
#  [     491.99      321.72]
#  [      492.2      322.07]
#  [     492.96      320.33]
#  [     491.66      322.11]]
# Generated Points Around Center: [[     496.72      314.54]
#  [     495.69      316.44]
#  [     494.93      316.24]
#  [     495.67      315.58]
#  [     495.87      316.15]
#  [     496.24      314.72]
#  [     495.74      314.97]
#  [     496.47         316]
#  [     495.12      315.51]
#  [     496.11      315.89]]
# Determined Direction: Up
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.60m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     247.54      253.32]
#  [     247.76      253.27]
#  [      246.9      252.94]
#  [     247.77       252.1]
#  [     248.54      253.27]
#  [     248.61      252.35]
#  [     248.54      253.16]
#  [     248.68      252.68]
#  [     246.92      252.49]
#  [     247.31      252.79]]
# Generated Points Around Center: [[     250.47      245.88]
#  [     249.89      245.22]
#  [     249.48      246.14]
#  [     249.13      245.66]
#  [     249.52      246.28]
#  [     250.76      245.72]
#  [     250.93      246.47]
#  [     250.92      245.72]
#  [     250.74      246.99]
#  [     249.65      246.62]]
# Determined Direction: Up
#
# 0: 480x640 1 RICK, 1 TW, 19.9ms
# Speed: 2.8ms preprocess, 19.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.52m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     495.26      315.17]
#  [     495.25      316.37]
#  [     495.04      315.86]
#  [     496.18      315.05]
#  [     494.81      315.57]
#  [     495.83      314.91]
#  [     496.16      316.35]
#  [     495.36      314.81]
#  [     495.98      315.14]
#  [     496.43      315.11]]
# Generated Points Around Center: [[     498.64       319.9]
#  [     497.51      321.07]
#  [     499.09      321.18]
#  [      499.1      321.01]
#  [     498.07      320.19]
#  [     497.88       319.5]
#  [     498.89      321.02]
#  [     498.42      320.14]
#  [     498.11      320.33]
#  [      497.6      319.54]]
# Determined Direction: Down
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.61m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     250.28      245.72]
#  [     251.05      245.56]
#  [     249.29      246.03]
#  [     250.06      247.06]
#  [     250.42      246.43]
#  [     251.07      246.18]
#  [     250.75       246.6]
#  [     251.07      245.33]
#  [     250.62      245.77]
#  [     249.51      246.73]]
# Generated Points Around Center: [[     254.82      250.55]
#  [     255.54      249.47]
#  [     254.51      249.17]
#  [     255.76      249.73]
#  [     255.34       249.6]
#  [     255.84      250.24]
#  [     254.83      250.57]
#  [     255.58      248.98]
#  [     254.17      249.74]
#  [     254.13      248.66]]
# Determined Direction: Center
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.51m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     499.31       320.7]
#  [     499.21      319.74]
#  [     497.83      320.68]
#  [     498.15      320.39]
#  [     497.89      320.16]
#  [     499.28      320.05]
#  [     497.85      319.38]
#  [     499.21      319.62]
#  [     497.92      319.38]
#  [     499.18      321.06]]
# Generated Points Around Center: [[     497.89      321.75]
#  [     496.74      322.34]
#  [     497.15      322.09]
#  [     497.57      322.19]
#  [     497.41      322.21]
#  [     496.41      322.55]
#  [     496.35      322.97]
#  [     497.17      323.23]
#  [     497.24      322.57]
#  [     496.99      321.96]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.91, Distance: 1.62m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     254.06      250.44]
#  [     254.09      250.16]
#  [     255.36      249.74]
#  [     254.11      250.09]
#  [        255      249.32]
#  [     254.57      250.11]
#  [     254.31      249.85]
#  [     255.47      250.16]
#  [     255.57      249.31]
#  [     254.31      249.37]]
# Generated Points Around Center: [[     254.04         250]
#  [     252.81      248.89]
#  [     254.08      248.92]
#  [     253.47       250.3]
#  [      254.2      250.22]
#  [      254.3      249.45]
#  [      254.3      249.15]
#  [     253.59      248.49]
#  [     252.49      248.56]
#  [     254.18      248.79]]
# Determined Direction: Center
# Track ID: 8, Class: LMV, Confidence: 0.31, Distance: 6.34m
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 27.9ms
# Speed: 4.5ms preprocess, 27.9ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.50m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     497.81      321.75]
#  [      496.4       322.2]
#  [     497.17      323.31]
#  [     496.22      322.39]
#  [        496      322.65]
#  [     496.43       323.2]
#  [     497.56      323.01]
#  [     497.56      323.44]
#  [     496.47      323.38]
#  [     497.31      321.96]]
# Generated Points Around Center: [[     498.65      318.26]
#  [     496.92      319.25]
#  [     497.08      319.51]
#  [     497.71      317.83]
#  [      497.8      319.27]
#  [     497.69       318.4]
#  [     498.46      319.47]
#  [     497.95       318.6]
#  [     498.23      319.51]
#  [     498.39      319.43]]
# Determined Direction: Up
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.61m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     253.97      249.06]
#  [     254.13      250.04]
#  [     253.06      248.94]
#  [     253.07      249.34]
#  [     252.93      249.42]
#  [     254.17      248.52]
#  [     252.49      250.23]
#  [     253.47      248.57]
#  [     253.82      250.14]
#  [     254.38      249.53]]
# Generated Points Around Center: [[      255.8      247.38]
#  [     254.05      246.92]
#  [     254.29      247.46]
#  [     255.11      247.72]
#  [     254.73      247.71]
#  [     254.67      247.99]
#  [     255.86      247.79]
#  [     255.65      248.07]
#  [     255.19      248.35]
#  [      254.7      247.68]]
# Determined Direction: Center
# Track ID: 8, Class: LMV, Confidence: 0.40, Distance: 6.49m
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 28.0ms
# Speed: 2.2ms preprocess, 28.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.94, Distance: 2.50m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.00 m/s²
# Generated Points Around Center: [[     498.65      319.42]
#  [     497.73      319.44]
#  [      497.6      317.87]
#  [     498.22      318.34]
#  [     496.75      318.91]
#  [     497.48      318.37]
#  [     498.05      319.23]
#  [     497.65      317.93]
#  [     497.86      318.41]
#  [     498.58       318.6]]
# Generated Points Around Center: [[     497.08      317.95]
#  [     497.93      317.81]
#  [     498.06      318.01]
#  [     496.79      319.07]
#  [     496.42      318.43]
#  [     496.39      318.49]
#  [     498.18      318.53]
#  [     497.69      319.54]
#  [     497.08      317.99]
#  [     498.26      317.87]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.60m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     255.17      247.65]
#  [     255.72      248.18]
#  [     254.53      247.97]
#  [     255.69      247.51]
#  [     255.12      248.47]
#  [     254.13      248.22]
#  [     254.66      248.62]
#  [     254.73       247.1]
#  [     254.54      248.17]
#  [     255.12      247.34]]
# Generated Points Around Center: [[     253.98      247.82]
#  [     254.27      247.16]
#  [     254.69      246.51]
#  [     254.33      246.45]
#  [     254.15      247.18]
#  [     253.84      247.43]
#  [      255.3      248.02]
#  [     255.29       246.4]
#  [     254.89      247.55]
#  [     253.76      246.84]]
# Determined Direction: Center
# Track ID: 8, Class: LMV, Confidence: 0.24, Distance: 6.49m
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 31.4ms
# Speed: 2.3ms preprocess, 31.4ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.50m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     496.51      317.78]
#  [     496.43      319.06]
#  [     498.11      317.84]
#  [        497      319.09]
#  [     496.93      318.22]
#  [     497.24      317.97]
#  [     496.67       318.6]
#  [     498.11       317.9]
#  [     496.49      318.43]
#  [     496.33      319.41]]
# Generated Points Around Center: [[     498.42      320.29]
#  [      497.3      320.02]
#  [     498.69      318.74]
#  [     498.92      320.25]
#  [     497.85      318.68]
#  [     498.81      320.55]
#  [     498.45      320.34]
#  [     497.24      318.93]
#  [     497.72      320.07]
#  [     498.13       318.9]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.61m
# Calculated Velocity: 0.00 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     254.22      246.79]
#  [     254.92      247.26]
#  [     255.52      247.46]
#  [     254.63      247.01]
#  [     255.18      247.32]
#  [     255.17      247.32]
#  [     254.46      247.34]
#  [     255.69      248.22]
#  [      254.1      247.44]
#  [     254.94      247.33]]
# Generated Points Around Center: [[     254.83      248.77]
#  [     255.14       249.1]
#  [     255.18      249.79]
#  [     256.51      250.12]
#  [     255.94      250.07]
#  [     256.06      249.72]
#  [     254.87      248.73]
#  [     254.69      249.49]
#  [     255.48      249.08]
#  [      254.9      249.32]]
# Determined Direction: Down
# Track ID: 8, Class: LMV, Confidence: 0.38, Distance: 6.56m
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 29.6ms
# Speed: 2.5ms preprocess, 29.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 1, Class: TW, Confidence: 0.93, Distance: 2.51m
# Calculated Velocity: 0.01 m/s
# Calculated Acceleration: 0.01 m/s²
# Generated Points Around Center: [[     497.36      318.97]
#  [     498.13      318.67]
#  [     498.05      320.45]
#  [     497.42      320.32]
#  [     497.52      318.73]
#  [     498.36      319.39]
#  [     497.71      319.13]
#  [     497.77      319.09]
#  [     498.75      320.41]
#  [     498.94      318.77]]
# Generated Points Around Center: [[        501      314.95]
#  [     499.76      315.25]
#  [     501.17      315.82]
#  [     499.99      314.91]
#  [     501.35      315.52]
#  [     500.71      316.54]
#  [     501.53      315.74]
#  [     501.38       315.7]
#  [     500.07      315.63]
#  [     501.22      315.89]]
# Determined Direction: Center
# Track ID: 2, Class: RICK, Confidence: 0.92, Distance: 1.61m
# Calculated Velocity: 0.00 m/s
# ...
#  [     575.77      268.57]
#  [     576.68      270.16]
#  [     576.03      269.56]
#  [     576.45      270.12]]
# Determined Direction: Up
# Track ID: 289, Class: LMV, Confidence: 0.92, Distance: 3.24m
# Calculated Velocity: 0.43 m/s
# Calculated Acceleration: 0.17 m/s²
# Generated Points Around Center: [[     377.99      165.72]
#  [     378.07      166.23]
#  [      376.5       165.7]
#  [     376.64      165.58]
#  [     376.54      166.68]
#  [     376.99      167.19]
#  [     376.34      165.51]
#  [     377.43      166.27]
#  [        377      165.41]
#  [     377.68      166.67]]
# Generated Points Around Center: [[     399.12      159.74]
#  [     398.69      159.68]
#  [     399.91      158.92]
#  [     399.73      158.63]
#  [     399.56      159.49]
#  [     398.71      158.49]
#  [     400.35      158.87]
#  [     399.71      159.95]
#  [     399.78      160.13]
#  [     398.97      159.56]]
# Determined Direction: Right
# Track ID: 376, Class: TW, Confidence: 0.66, Distance: 1.84m
#
# 0: 480x640 1 LMV, 1 RICK, 2 TWs, 39.2ms
# Speed: 3.1ms preprocess, 39.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 235, Class: TW, Confidence: 0.88, Distance: 3.32m
# Calculated Velocity: 0.13 m/s
# Calculated Acceleration: 0.10 m/s²
# Generated Points Around Center: [[     250.89      186.89]
#  [      250.4      186.79]
#  [     250.57      186.27]
#  [     250.98      186.72]
#  [     250.67      185.29]
#  [     249.48      186.47]
#  [     250.34      186.42]
#  [     249.69       186.2]
#  [     250.24      185.64]
#  [     250.23       185.9]]
# Generated Points Around Center: [[     269.38      178.55]
#  [     267.77       179.2]
#  [     268.48      178.24]
#  [     269.38      177.99]
#  [     267.64      177.37]
#  [     268.44      179.15]
#  [     268.76      178.59]
#  [     268.64      177.58]
#  [     267.75      179.15]
#  [        268      179.16]]
# Determined Direction: Right
# Track ID: 327, Class: TW, Confidence: 0.12, Distance: 1.83m
# Calculated Velocity: 0.26 m/s
# Calculated Acceleration: 0.04 m/s²
# Generated Points Around Center: [[     575.55      269.01]
#  [     575.79      268.95]
#  [     575.51      269.86]
#  [     575.43      269.03]
#  [      576.1      269.12]
#  [      575.7      268.87]
#  [     575.83      268.95]
#  [     576.19      269.19]
#  [     575.61      269.37]
#  [     576.25       269.4]]
# Generated Points Around Center: [[     580.35      256.88]
#  [     579.82      256.95]
#  [     578.81      255.33]
#  [     579.18      256.62]
#  [      579.4      256.86]
#  [     578.82      256.52]
#  [     579.84      255.26]
#  [     579.05      255.23]
#  [     579.75         257]
#  [      579.9      256.94]]
# Determined Direction: Up
# Track ID: 289, Class: LMV, Confidence: 0.93, Distance: 3.41m
# Calculated Velocity: 0.27 m/s
# Calculated Acceleration: 0.15 m/s²
# Generated Points Around Center: [[     399.38      159.22]
#  [     399.83      158.76]
#  [     399.14      159.78]
#  [     400.26      158.33]
#  [        399      159.71]
#  [     399.55      160.18]
#  [     398.79      159.32]
#  [     398.93      158.43]
#  [     399.92      158.37]
#  [     399.36      159.23]]
# Generated Points Around Center: [[     417.09      154.84]
#  [     417.34      154.57]
#  [     418.57      155.95]
#  [     417.55      154.86]
#  [     417.13      154.53]
#  [      417.9      156.23]
#  [     418.26      156.11]
#  [      417.8      155.76]
#  [     417.47      154.73]
#  [     417.77      155.65]]
# Determined Direction: Right
# Track ID: 376, Class: RICK, Confidence: 0.43, Distance: 1.85m
#
# 0: 480x640 (no detections), 34.5ms
# Speed: 2.5ms preprocess, 34.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 2 LMVs, 1 RICK, 7 TWs, 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 2 LMVs, 1 RICK, 4 TWs, 22.8ms
# Speed: 2.4ms preprocess, 22.8ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.93, Distance: 3.83m
# Track ID: 379, Class: TW, Confidence: 0.90, Distance: 5.13m
# Track ID: 380, Class: LMV, Confidence: 0.56, Distance: 5.12m
# Track ID: 381, Class: TW, Confidence: 0.79, Distance: 7.09m
# Track ID: 382, Class: TW, Confidence: 0.83, Distance: 6.88m
# Track ID: 383, Class: TW, Confidence: 0.81, Distance: 7.71m
# Track ID: 384, Class: HMV, Confidence: 0.79, Distance: 6.51m
# Track ID: 385, Class: LMV, Confidence: 0.73, Distance: 7.67m
#
# 0: 480x640 2 LMVs, 1 RICK, 4 TWs, 29.8ms
# Speed: 2.7ms preprocess, 29.8ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.93, Distance: 3.80m
# Track ID: 379, Class: TW, Confidence: 0.91, Distance: 4.98m
# Track ID: 380, Class: LMV, Confidence: 0.91, Distance: 5.10m
# Track ID: 381, Class: TW, Confidence: 0.83, Distance: 6.48m
# Track ID: 382, Class: TW, Confidence: 0.87, Distance: 6.73m
# Track ID: 383, Class: TW, Confidence: 0.76, Distance: 7.64m
# Track ID: 384, Class: LMV, Confidence: 0.53, Distance: 6.61m
#
# 0: 480x640 1 HMV, 2 LMVs, 1 RICK, 6 TWs, 37.1ms
# Speed: 3.0ms preprocess, 37.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.93, Distance: 3.84m
# Track ID: 379, Class: TW, Confidence: 0.90, Distance: 4.93m
# Track ID: 380, Class: LMV, Confidence: 0.93, Distance: 5.11m
# Track ID: 381, Class: TW, Confidence: 0.87, Distance: 6.33m
# Track ID: 382, Class: TW, Confidence: 0.87, Distance: 6.65m
# Track ID: 383, Class: TW, Confidence: 0.74, Distance: 7.61m
# Track ID: 384, Class: HMV, Confidence: 0.47, Distance: 6.62m
# Track ID: 390, Class: TW, Confidence: 0.73, Distance: 7.76m
# Track ID: 393, Class: TW, Confidence: 0.72, Distance: 7.82m
# Track ID: 395, Class: LMV, Confidence: 0.44, Distance: 6.77m
#
# 0: 480x640 3 LMVs, 1 RICK, 7 TWs, 29.9ms
# Speed: 3.2ms preprocess, 29.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.93, Distance: 3.86m
# Track ID: 379, Class: TW, Confidence: 0.89, Distance: 4.84m
# Track ID: 380, Class: LMV, Confidence: 0.92, Distance: 5.11m
# Track ID: 381, Class: TW, Confidence: 0.87, Distance: 6.25m
# Track ID: 382, Class: TW, Confidence: 0.85, Distance: 6.68m
# Track ID: 383, Class: TW, Confidence: 0.71, Distance: 7.62m
# Track ID: 384, Class: LMV, Confidence: 0.53, Distance: 6.65m
# Track ID: 390, Class: TW, Confidence: 0.64, Distance: 7.77m
# Track ID: 393, Class: TW, Confidence: 0.59, Distance: 7.83m
# Track ID: 395, Class: LMV, Confidence: 0.16, Distance: 7.02m
# Track ID: 396, Class: TW, Confidence: 0.56, Distance: 7.65m
#
# 0: 480x640 4 LMVs, 1 RICK, 7 TWs, 39.4ms
# Speed: 3.0ms preprocess, 39.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.92, Distance: 3.84m
# Track ID: 379, Class: TW, Confidence: 0.90, Distance: 4.86m
# Track ID: 380, Class: LMV, Confidence: 0.94, Distance: 5.07m
# Track ID: 381, Class: TW, Confidence: 0.88, Distance: 6.26m
# Track ID: 382, Class: TW, Confidence: 0.87, Distance: 6.69m
# Track ID: 383, Class: TW, Confidence: 0.57, Distance: 7.61m
# Track ID: 384, Class: LMV, Confidence: 0.35, Distance: 6.56m
# Track ID: 390, Class: TW, Confidence: 0.70, Distance: 7.73m
# Track ID: 393, Class: TW, Confidence: 0.38, Distance: 7.82m
# Track ID: 395, Class: LMV, Confidence: 0.59, Distance: 6.68m
# Track ID: 398, Class: TW, Confidence: 0.51, Distance: 7.69m
# Track ID: 399, Class: LMV, Confidence: 0.43, Distance: 7.74m
#
# 0: 480x640 1 HMV, 3 LMVs, 1 RICK, 8 TWs, 35.5ms
# Speed: 2.7ms preprocess, 35.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.92, Distance: 3.86m
# Track ID: 379, Class: TW, Confidence: 0.91, Distance: 4.93m
# Track ID: 380, Class: LMV, Confidence: 0.92, Distance: 5.14m
# Track ID: 381, Class: TW, Confidence: 0.88, Distance: 6.21m
# Track ID: 382, Class: TW, Confidence: 0.86, Distance: 6.68m
# Track ID: 383, Class: TW, Confidence: 0.52, Distance: 7.63m
# Track ID: 384, Class: HMV, Confidence: 0.48, Distance: 6.64m
# Track ID: 390, Class: TW, Confidence: 0.70, Distance: 7.75m
# Track ID: 393, Class: TW, Confidence: 0.61, Distance: 7.83m
# Track ID: 395, Class: LMV, Confidence: 0.62, Distance: 6.70m
# Track ID: 398, Class: TW, Confidence: 0.38, Distance: 7.76m
# Track ID: 399, Class: LMV, Confidence: 0.21, Distance: 7.76m
# Track ID: 396, Class: TW, Confidence: 0.44, Distance: 7.65m
#
# 0: 480x640 4 LMVs, 1 RICK, 8 TWs, 36.1ms
# Speed: 2.9ms preprocess, 36.1ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.92, Distance: 3.84m
# Track ID: 379, Class: TW, Confidence: 0.91, Distance: 5.01m
# Track ID: 380, Class: LMV, Confidence: 0.92, Distance: 5.13m
# Track ID: 381, Class: TW, Confidence: 0.88, Distance: 6.27m
# Track ID: 382, Class: TW, Confidence: 0.86, Distance: 6.68m
# Track ID: 383, Class: TW, Confidence: 0.62, Distance: 7.63m
# Track ID: 384, Class: LMV, Confidence: 0.34, Distance: 6.58m
# Track ID: 390, Class: TW, Confidence: 0.73, Distance: 7.72m
# Track ID: 393, Class: TW, Confidence: 0.36, Distance: 7.79m
# Track ID: 395, Class: LMV, Confidence: 0.76, Distance: 6.69m
# Track ID: 398, Class: TW, Confidence: 0.25, Distance: 7.74m
# Track ID: 399, Class: LMV, Confidence: 0.43, Distance: 7.76m
# Track ID: 396, Class: TW, Confidence: 0.23, Distance: 7.64m
#
# 0: 480x640 3 LMVs, 1 RICK, 6 TWs, 38.7ms
# Speed: 2.6ms preprocess, 38.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.92, Distance: 3.86m
# Track ID: 379, Class: TW, Confidence: 0.92, Distance: 5.01m
# Track ID: 380, Class: LMV, Confidence: 0.92, Distance: 5.27m
# Track ID: 381, Class: TW, Confidence: 0.86, Distance: 6.51m
# Track ID: 382, Class: TW, Confidence: 0.86, Distance: 6.74m
# Track ID: 383, Class: TW, Confidence: 0.13, Distance: 7.64m
# Track ID: 384, Class: LMV, Confidence: 0.26, Distance: 6.59m
# Track ID: 390, Class: TW, Confidence: 0.64, Distance: 7.63m
# Track ID: 393, Class: TW, Confidence: 0.19, Distance: 7.82m
# Track ID: 395, Class: LMV, Confidence: 0.79, Distance: 6.69m
#
# 0: 480x640 1 HMV, 2 LMVs, 1 RICK, 6 TWs, 33.3ms
# Speed: 3.4ms preprocess, 33.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.92, Distance: 3.85m
# Track ID: 379, Class: TW, Confidence: 0.90, Distance: 5.12m
# Track ID: 380, Class: LMV, Confidence: 0.91, Distance: 5.29m
# Track ID: 381, Class: TW, Confidence: 0.89, Distance: 6.35m
# Track ID: 382, Class: TW, Confidence: 0.89, Distance: 6.71m
# Track ID: 383, Class: TW, Confidence: 0.65, Distance: 7.64m
# Track ID: 384, Class: HMV, Confidence: 0.34, Distance: 6.57m
# Track ID: 390, Class: TW, Confidence: 0.76, Distance: 7.63m
# Track ID: 393, Class: TW, Confidence: 0.39, Distance: 7.81m
# Track ID: 395, Class: LMV, Confidence: 0.68, Distance: 6.99m
#
# 0: 480x640 1 HMV, 2 LMVs, 1 RICK, 5 TWs, 31.9ms
# Speed: 2.8ms preprocess, 31.9ms inference, 11.8ms postprocess per image at shape (1, 3, 480, 640)
# Track ID: 378, Class: RICK, Confidence: 0.93, Distance: 3.87m
# Calculated Velocity: 0.03 m/s
# Generated Points Around Center: [[     275.53      260.38]
#  [     275.82      260.92]
#  [     276.41      261.66]
#  [     274.49      261.46]
#  [     275.89      261.21]
#  [     276.26      261.63]
#  [     275.69      260.59]
#  [     276.35      261.07]
#  [     276.41      261.71]
#  [     276.32      261.53]]
# Generated Points Around Center: [[     268.81      231.85]
#  [     268.09       231.9]
#  [     268.68      233.17]
#  [      267.1      233.17]
#  [     268.46      233.21]
#  [      267.6      233.09]
#  [     268.19      232.04]
#  [      268.8      231.65]
#  [     268.09      232.09]
#  [     268.44      232.39]]
# Determined Direction: Up
# Track ID: 379, Class: TW, Confidence: 0.91, Distance: 5.15m
# Calculated Velocity: 0.02 m/s
# Generated Points Around Center: [[     459.54      303.89]
#  [     458.87      303.43]
#  [      459.7      303.04]
#  [        460      302.46]
#  [     459.77      302.53]
#  [     458.72      302.74]
#  [     459.75      302.39]
#  [     460.01      303.49]
#  [     458.82      303.18]
#  [     460.31      303.12]]
# Generated Points Around Center: [[     450.59      272.39]
#  [     449.68      273.87]
#  [     450.51      272.82]
#  [     451.48      272.16]
#  [     451.12      272.34]
#  [     449.81      273.54]
#  [     449.99      273.45]
#  [      450.6      272.69]
#  [     450.77      272.57]
#  [     449.76         273]]
# Determined Direction: Up
# Track ID: 380, Class: LMV, Confidence: 0.88, Distance: 5.22m
# Calculated Velocity: 0.07 m/s
# Generated Points Around Center: [[     38.841      252.82]
#  [     38.577      251.54]
#  [     38.691       252.1]
#  [     39.261      251.54]
#  [     37.598      251.92]
#  [      39.12      252.76]
#  [     37.479      251.15]
#  [     39.059      251.73]
#  [     38.687      251.63]
#  [     39.229      251.72]]
# Generated Points Around Center: [[     37.181      223.53]
#  [     37.476      222.79]
#  [     36.875      223.97]
#  [     37.741      224.46]
#  [     37.432      223.38]
#  [     37.472      223.05]
#  [      36.73      224.15]
#  [     37.831      224.33]
#  [     37.908      223.99]
#  [     37.295      223.09]]
# Determined Direction: Up
# Track ID: 381, Class: TW, Confidence: 0.82, Distance: 6.72m
# Calculated Velocity: 0.26 m/s
# Generated Points Around Center: [[     94.044      288.98]
#  [     94.122      289.43]
#  [     94.437      290.35]
#  [     94.145       289.8]
#  [     93.534      289.43]
#  [     93.399      290.39]
#  [     94.193      289.25]
#  [      93.05      290.36]
#  [     93.141      289.21]
#  [      93.71      289.43]]
# Generated Points Around Center: [[      89.13      252.22]
#  [      90.23      251.16]
#  [     90.069      251.16]
#  [      90.55      252.87]
#  [     90.752      252.32]
#  [     89.218      251.98]
#  [     90.369      251.02]
#  [     89.477      251.46]
#  [     89.574      251.19]
#  [     90.307      251.62]]
# Determined Direction: Up
# Track ID: 382, Class: TW, Confidence: 0.87, Distance: 6.74m
# Calculated Velocity: 0.10 m/s
# Generated Points Around Center: [[     369.72      285.79]
#  [     368.85      286.17]
#  [     368.74      286.49]
#  [     368.71      285.53]
#  [     370.43      285.63]
#  [     369.78      286.77]
#  [     369.57      286.87]
#  [     369.51      286.41]
#  [     369.78      285.53]
#  [     370.31      285.67]]
# Generated Points Around Center: [[     358.78      255.86]
#  [     358.89      254.75]
#  [     359.73      256.05]
#  [     359.36      256.39]
#  [     359.23      256.39]
#  [     359.17      255.02]
#  [     359.05      255.47]
#  [     357.84      255.41]
#  [     359.71      256.48]
#  [      358.8      256.22]]
# Determined Direction: Up
# Track ID: 383, Class: TW, Confidence: 0.65, Distance: 7.64m
# Calculated Velocity: 0.05 m/s
# Generated Points Around Center: [[     152.22      283.03]
#  [     152.07      281.37]
#  [     151.78      282.12]
#  [     151.02       283.1]
#  [     150.84      281.94]
#  [     151.41       282.9]
#  [     150.85      281.79]
#  [     150.44      282.39]
#  [      151.6      281.83]
#  [     151.14      282.83]]
# Generated Points Around Center: [[     145.06      251.59]
#  [     144.74      249.67]
#  [     144.71      250.48]
#  [     144.66      251.48]
#  [     144.92      249.87]
#  [     145.05      250.19]
#  [        145       250.4]
#  [     144.74      251.02]
#  [     145.56      250.01]
#  [     145.19      251.37]]
# Determined Direction: Up
# Track ID: 384, Class: HMV, Confidence: 0.78, Distance: 6.59m
# Calculated Velocity: 0.05 m/s
# Generated Points Around Center: [[     177.33      250.03]
#  [     177.25      250.09]
#  [     177.35      250.16]
#  [     178.17      250.35]
#  [     177.23      250.95]
#  [     178.56      249.75]
#  [     177.79      250.83]
#  [     177.98      250.52]
#  [     178.34      250.95]
#  [     177.81      250.24]]
# Generated Points Around Center: [[     173.47      223.57]
#  [     173.22      223.22]
#  [     173.91      222.97]
#  [     173.79      222.05]
#  [     173.51      222.47]
#  [     173.23      222.62]
#  [     172.09      222.53]
#  [      173.8      223.91]
#  [     173.73      223.99]
#  [      172.8      223.13]]
# Determined Direction: Up
# Track ID: 390, Class: TW, Confidence: 0.68, Distance: 7.62m
# Track ID: 395, Class: LMV, Confidence: 0.41, Distance: 7.13m

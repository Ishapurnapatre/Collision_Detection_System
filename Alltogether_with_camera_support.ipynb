# %%
import cv2
from ultralytics import YOLO
import numpy as np
from collections import deque, Counter, defaultdict
import os

class ObjectTracker:
    def __init__(self, model_path='yolov8_aug.pt', max_history_len=5, max_direction_len=5, movement_threshold=5, frame_rate=30):
        self.model = YOLO(model_path)
        self.cap = cv2.VideoCapture(0)  # Use live webcam instead of a video file
        
        # Increase camera resolution for better quality
        self.cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)  # Full HD width
        self.cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)  # Full HD height
        self.cap.set(cv2.CAP_PROP_FPS, 30)  # Set FPS to 30 for smoothness
        
        self.prev_frame = None
        self.vehicle_histories = defaultdict(lambda: deque(maxlen=max_history_len))
        self.vehicle_directions = defaultdict(lambda: deque(maxlen=max_direction_len))
        self.vehicle_direction_start_time = defaultdict(lambda: cv2.getTickCount())  # Initialize direction start times
        self.colors = np.random.randint(0, 255, (100, 3))  # Random colors for tracking lines
        self.mask = None
        self.max_history_len = max_history_len
        self.max_direction_len = max_direction_len
        self.movement_threshold = movement_threshold
        self.frame_rate = frame_rate  # Assuming 30 FPS
        
        # Define output video path (Desktop) and use MP4 format
        desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")
        self.output_path = os.path.join(desktop_path, "processed_video.mp4")

        # Video writer setup for MP4 format
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # 'mp4v' is the codec for MP4 format
        self.frame_width = int(self.cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        self.frame_height = int(self.cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        self.out = cv2.VideoWriter(self.output_path, fourcc, 30, (self.frame_width, self.frame_height))

    def run_tracking(self):
        if not self.cap.isOpened():
            print("Error opening webcam")
            return
        
        ret, frame = self.cap.read()
        if not ret:
            print("Failed to read from webcam")
            return

        self.prev_frame = frame.copy()
        self.mask = np.zeros_like(frame)  # Initialize mask to match frame dimensions

        while self.cap.isOpened():
            success, frame = self.cap.read()
            
            if not success:
                break
            
            annotated_frame = self.process_frame(frame)

            # Save the processed frame to video
            self.out.write(annotated_frame)

            cv2.imshow("YOLOv8 Live Tracking", annotated_frame)
            
            if cv2.waitKey(1) & 0xFF == ord('q'):  # Press 'q' to exit
                break
        
        self.cap.release()
        self.out.release()  # Release video writer
        cv2.destroyAllWindows()
        print(f"Processed video saved at: {self.output_path}")

    def get_around_center(self, center_x, center_y, distance):
        pixels_around_center = [
            (center_x + distance, center_y),
            (center_x - distance, center_y),
            (center_x, center_y + distance),
            (center_x, center_y - distance),
            (center_x + distance, center_y + distance),
            (center_x + distance, center_y - distance),
            (center_x - distance, center_y + distance),
            (center_x - distance, center_y - distance),
            (center_x + distance // 2, center_y + distance // 2),
            (center_x - distance // 2, center_y - distance // 2)
        ]
        return pixels_around_center

    def process_frame(self, frame):
        # Reduce blurriness & improve sharpness
        frame = cv2.GaussianBlur(frame, (5, 5), 0)  # Apply Gaussian blur to smooth noise
        frame = cv2.detailEnhance(frame, sigma_s=10, sigma_r=0.15)  # Enhance details
        
        results = self.model.track(frame, persist=True)
        annotated_frame = frame.copy()

        if results and len(results) > 0 and hasattr(results[0], 'boxes') and results[0].boxes:
            boxes = results[0].boxes

            if hasattr(boxes, 'xywh') and hasattr(boxes, 'id') and boxes.id is not None:
                track_ids = boxes.id.int().cpu().tolist()
                boxes_xywh = boxes.xywh.cpu().numpy()
                class_names = [results[0].names[i] for i in boxes.cls.int().cpu().tolist()]
                confidences = boxes.conf.cpu().tolist()

                for box, track_id, class_name in zip(boxes_xywh, track_ids, class_names):
                    x, y, w, h = box
                    x1, y1 = int(x - w / 2), int(y - h / 2)
                    x2, y2 = int(x + w / 2), int(y + h / 2)

                    # Draw bounding box
                    cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)

                    # Safe access to confidence
                    conf = confidences[track_ids.index(track_id)] if track_id < len(confidences) else 0

                    # Add current position to history
                    center_x = (x1 + x2) // 2
                    center_y = (y1 + y2) // 2
                    self.vehicle_histories[track_id].append((center_x, center_y))

                    # Draw center of bounding box
                    cv2.circle(annotated_frame, (center_x, center_y), 5, (0, 0, 255), -1)

                    # Calculate velocity
                    velocity = None
                    if len(self.vehicle_histories[track_id]) > 1:
                        prev_center = self.vehicle_histories[track_id][-2]
                        velocity = self.calculate_velocity(prev_center, (center_x, center_y))
                    
                    velocity_str = f"Vel: {velocity:.2f} px/s" if velocity else "Vel: N/A"
                    confidence_str = f"Conf: {conf:.2f}"

                    # Display tracking info
                    cv2.putText(annotated_frame, f"ID: {track_id}", (int(x1), int(y1 - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
                    cv2.putText(annotated_frame, f"Class: {class_name}", (int(x1), int(y1 - 25)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
                    cv2.putText(annotated_frame, confidence_str, (int(x1), int(y1 - 40)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
                    cv2.putText(annotated_frame, velocity_str, (int(x1), int(y1 - 55)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

        return annotated_frame

    def calculate_velocity(self, old_pos, new_pos):
        dx = new_pos[0] - old_pos[0]
        dy = new_pos[1] - old_pos[1]
        distance = np.sqrt(dx**2 + dy**2)
        velocity = distance * self.frame_rate  # pixels per second
        return velocity

# Run live tracking
tracker = ObjectTracker()
tracker.run_tracking()
# Out:
# 0: 480x640 1 RICK, 38.4ms
# Speed: 4.6ms preprocess, 38.4ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 41.8ms
# Speed: 3.3ms preprocess, 41.8ms inference, 13.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 32.4ms
# Speed: 6.6ms preprocess, 32.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 42.6ms
# Speed: 4.0ms preprocess, 42.6ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 44.6ms
# Speed: 2.8ms preprocess, 44.6ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 58.5ms
# Speed: 3.1ms preprocess, 58.5ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 44.8ms
# Speed: 5.7ms preprocess, 44.8ms inference, 10.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 24.3ms
# Speed: 2.8ms preprocess, 24.3ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 39.1ms
# Speed: 2.6ms preprocess, 39.1ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 47.9ms
# Speed: 3.3ms preprocess, 47.9ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 54.4ms
# Speed: 2.9ms preprocess, 54.4ms inference, 14.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 HMVs, 22.7ms
# Speed: 2.3ms preprocess, 22.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 HMVs, 24.6ms
# Speed: 2.3ms preprocess, 24.6ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 28.0ms
# Speed: 3.3ms preprocess, 28.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.0ms
# Speed: 3.5ms preprocess, 23.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.0ms
# Speed: 2.9ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 32.5ms
# Speed: 4.9ms preprocess, 32.5ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 30.2ms
# Speed: 2.9ms preprocess, 30.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.6ms
# Speed: 2.5ms preprocess, 24.6ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.2ms
# Speed: 3.0ms preprocess, 30.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 28.9ms
# Speed: 8.0ms preprocess, 28.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 30.2ms
# Speed: 3.0ms preprocess, 30.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 32.0ms
# Speed: 2.8ms preprocess, 32.0ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 TWs, 35.0ms
# Speed: 3.2ms preprocess, 35.0ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 34.0ms
# Speed: 2.4ms preprocess, 34.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.1ms
# Speed: 2.7ms preprocess, 31.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 34.4ms
# Speed: 6.0ms preprocess, 34.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 31.3ms
# Speed: 2.4ms preprocess, 31.3ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 RICK, 1 TW, 31.2ms
# Speed: 3.0ms preprocess, 31.2ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 32.0ms
# Speed: 2.3ms preprocess, 32.0ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 59.0ms
# Speed: 3.1ms preprocess, 59.0ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.4ms
# Speed: 4.1ms preprocess, 24.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 37.9ms
# Speed: 4.7ms preprocess, 37.9ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 36.3ms
# Speed: 2.7ms preprocess, 36.3ms inference, 13.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 55.8ms
# Speed: 2.9ms preprocess, 55.8ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 RICK, 25.8ms
# Speed: 2.6ms preprocess, 25.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 39.2ms
# Speed: 2.7ms preprocess, 39.2ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 23.2ms
# Speed: 3.2ms preprocess, 23.2ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 27.2ms
# Speed: 4.2ms preprocess, 27.2ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.1ms
# Speed: 2.5ms preprocess, 41.1ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 26.9ms
# Speed: 4.3ms preprocess, 26.9ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 30.4ms
# Speed: 2.2ms preprocess, 30.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.1ms
# Speed: 7.0ms preprocess, 23.1ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.0ms
# Speed: 3.5ms preprocess, 23.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 29.2ms
# Speed: 3.5ms preprocess, 29.2ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 HMVs, 32.2ms
# Speed: 6.8ms preprocess, 32.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.1ms
# Speed: 2.3ms preprocess, 29.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 6.6ms preprocess, 25.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.3ms
# Speed: 3.8ms preprocess, 29.3ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 46.4ms
# Speed: 3.2ms preprocess, 46.4ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 24.5ms
# Speed: 2.3ms preprocess, 24.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 22.8ms
# Speed: 2.8ms preprocess, 22.8ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 22.7ms
# Speed: 2.8ms preprocess, 22.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 49.2ms
# Speed: 2.7ms preprocess, 49.2ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 26.2ms
# Speed: 2.5ms preprocess, 26.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 HMVs, 30.7ms
# Speed: 2.5ms preprocess, 30.7ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.7ms
# Speed: 2.5ms preprocess, 24.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 29.8ms
# Speed: 2.6ms preprocess, 29.8ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 40.8ms
# Speed: 4.5ms preprocess, 40.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.4ms
# Speed: 2.5ms preprocess, 29.4ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.7ms
# Speed: 2.6ms preprocess, 22.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 2.7ms preprocess, 25.0ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.3ms
# Speed: 2.8ms preprocess, 37.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.2ms
# Speed: 4.6ms preprocess, 25.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.4ms
# Speed: 3.0ms preprocess, 23.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 5.2ms preprocess, 25.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.6ms
# Speed: 2.2ms preprocess, 29.6ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING: not enough matching points
# 0: 480x640 1 HMV, 1 LMV, 25.0ms
# Speed: 4.1ms preprocess, 25.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.4ms
# Speed: 2.7ms preprocess, 30.4ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.7ms
# Speed: 2.7ms preprocess, 22.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.9ms
# Speed: 2.6ms preprocess, 29.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.9ms
# Speed: 3.3ms preprocess, 29.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.5ms
# Speed: 3.2ms preprocess, 27.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING: not enough matching points
# 0: 480x640 1 HMV, 23.2ms
# Speed: 4.5ms preprocess, 23.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.6ms
# Speed: 2.2ms preprocess, 29.6ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.2ms
# Speed: 4.8ms preprocess, 29.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 25.4ms
# Speed: 2.4ms preprocess, 25.4ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.5ms
# Speed: 4.5ms preprocess, 23.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.3ms
# Speed: 2.5ms preprocess, 33.3ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 HMVs, 22.6ms
# Speed: 2.4ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.2ms
# Speed: 3.2ms preprocess, 60.2ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.4ms
# Speed: 2.8ms preprocess, 24.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.8ms
# Speed: 7.2ms preprocess, 26.8ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.7ms
# Speed: 2.4ms preprocess, 28.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 TW, 32.7ms
# Speed: 3.3ms preprocess, 32.7ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.8ms
# Speed: 2.5ms preprocess, 41.8ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 27.7ms
# Speed: 2.3ms preprocess, 27.7ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.7ms
# Speed: 2.4ms preprocess, 25.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 25.3ms
# Speed: 5.5ms preprocess, 25.3ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 24.7ms
# Speed: 2.5ms preprocess, 24.7ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.7ms
# Speed: 2.7ms preprocess, 37.7ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.1ms
# Speed: 3.3ms preprocess, 61.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.9ms
# Speed: 2.7ms preprocess, 22.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 2.9ms preprocess, 59.5ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.1ms
# Speed: 3.3ms preprocess, 29.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.5ms
# Speed: 2.6ms preprocess, 29.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.9ms
# Speed: 7.8ms preprocess, 36.9ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.7ms
# Speed: 3.3ms preprocess, 22.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.9ms
# Speed: 2.8ms preprocess, 27.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.1ms
# Speed: 2.7ms preprocess, 43.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.0ms
# Speed: 2.3ms preprocess, 33.0ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.1ms
# Speed: 2.5ms preprocess, 25.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.6ms
# Speed: 2.7ms preprocess, 24.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.6ms
# Speed: 3.3ms preprocess, 24.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING: not enough matching points
# 0: 480x640 1 TW, 40.9ms
# Speed: 2.6ms preprocess, 40.9ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.2ms
# Speed: 2.4ms preprocess, 24.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.2ms
# Speed: 2.7ms preprocess, 30.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.3ms
# Speed: 2.7ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.4ms
# Speed: 2.9ms preprocess, 30.4ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.2ms
# Speed: 3.3ms preprocess, 33.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING: not enough matching points
# 0: 480x640 1 LMV, 40.7ms
# Speed: 4.4ms preprocess, 40.7ms inference, 13.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.6ms
# Speed: 2.6ms preprocess, 22.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 41.9ms
# Speed: 2.8ms preprocess, 41.9ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.1ms
# Speed: 2.6ms preprocess, 32.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 21.4ms
# Speed: 3.5ms preprocess, 21.4ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.2ms
# Speed: 2.2ms preprocess, 42.2ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 34.2ms
# Speed: 2.2ms preprocess, 34.2ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.7ms
# Speed: 2.4ms preprocess, 29.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.2ms
# Speed: 5.9ms preprocess, 23.2ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.8ms
# Speed: 3.9ms preprocess, 24.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.3ms
# Speed: 3.0ms preprocess, 32.3ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.8ms
# Speed: 3.6ms preprocess, 31.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 31.2ms
# Speed: 2.3ms preprocess, 31.2ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 22.7ms
# Speed: 2.3ms preprocess, 22.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 30.0ms
# Speed: 2.6ms preprocess, 30.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 47.2ms
# Speed: 2.6ms preprocess, 47.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 22.9ms
# Speed: 2.4ms preprocess, 22.9ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.6ms
# Speed: 6.7ms preprocess, 23.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 TW, 22.8ms
# Speed: 2.5ms preprocess, 22.8ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 TW, 29.0ms
# Speed: 2.4ms preprocess, 29.0ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 22.7ms
# Speed: 2.4ms preprocess, 22.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 29.1ms
# Speed: 2.6ms preprocess, 29.1ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.2ms
# Speed: 3.2ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.9ms
# Speed: 2.3ms preprocess, 24.9ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 23.0ms
# Speed: 2.8ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 3 TWs, 28.9ms
# Speed: 3.6ms preprocess, 28.9ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 1 RICK, 30.6ms
# Speed: 2.3ms preprocess, 30.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 25.5ms
# Speed: 3.1ms preprocess, 25.5ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 1 TW, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 23.1ms
# Speed: 4.6ms preprocess, 23.1ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 32.8ms
# Speed: 6.7ms preprocess, 32.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 2 TWs, 60.4ms
# Speed: 2.9ms preprocess, 60.4ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 32.8ms
# Speed: 2.8ms preprocess, 32.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 34.6ms
# Speed: 2.9ms preprocess, 34.6ms inference, 12.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 23.0ms
# Speed: 2.6ms preprocess, 23.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.8ms
# Speed: 2.8ms preprocess, 39.8ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 1 TW, 25.6ms
# Speed: 2.7ms preprocess, 25.6ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 31.5ms
# Speed: 2.4ms preprocess, 31.5ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.8ms
# Speed: 5.5ms preprocess, 24.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 28.2ms
# Speed: 3.5ms preprocess, 28.2ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 33.0ms
# Speed: 2.7ms preprocess, 33.0ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 24.6ms
# Speed: 2.2ms preprocess, 24.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 33.7ms
# Speed: 2.6ms preprocess, 33.7ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 2 RICKs, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 28.9ms
# Speed: 2.7ms preprocess, 28.9ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 45.4ms
# Speed: 2.5ms preprocess, 45.4ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 22.7ms
# Speed: 3.1ms preprocess, 22.7ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 1 TW, 47.3ms
# Speed: 2.9ms preprocess, 47.3ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 37.4ms
# Speed: 4.1ms preprocess, 37.4ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 24.7ms
# Speed: 2.3ms preprocess, 24.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 24.8ms
# Speed: 2.5ms preprocess, 24.8ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.0ms
# Speed: 3.4ms preprocess, 23.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.5ms
# Speed: 2.7ms preprocess, 32.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.6ms
# Speed: 2.5ms preprocess, 27.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 30.1ms
# Speed: 2.5ms preprocess, 30.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.0ms
# Speed: 7.0ms preprocess, 26.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.2ms
# Speed: 2.4ms preprocess, 30.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 34.5ms
# Speed: 3.8ms preprocess, 34.5ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 1 TW, 30.8ms
# Speed: 2.6ms preprocess, 30.8ms inference, 13.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 23.0ms
# Speed: 2.2ms preprocess, 23.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.9ms
# Speed: 2.7ms preprocess, 47.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 40.9ms
# Speed: 4.8ms preprocess, 40.9ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 22.7ms
# Speed: 2.3ms preprocess, 22.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 36.8ms
# Speed: 2.5ms preprocess, 36.8ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.3ms
# Speed: 2.3ms preprocess, 37.3ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 22.4ms
# Speed: 2.2ms preprocess, 22.4ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 1 TW, 29.5ms
# Speed: 2.7ms preprocess, 29.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.5ms
# Speed: 2.5ms preprocess, 28.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 25.8ms
# Speed: 2.8ms preprocess, 25.8ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.1ms
# Speed: 3.1ms preprocess, 30.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 31.0ms
# Speed: 2.9ms preprocess, 31.0ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.9ms
# Speed: 2.3ms preprocess, 22.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 2.9ms preprocess, 43.5ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.9ms
# Speed: 3.8ms preprocess, 45.9ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.4ms
# Speed: 2.4ms preprocess, 20.4ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 29.9ms
# Speed: 2.4ms preprocess, 29.9ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 25.6ms
# Speed: 2.9ms preprocess, 25.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 RICKs, 29.4ms
# Speed: 2.5ms preprocess, 29.4ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 RICK, 27.3ms
# Speed: 3.9ms preprocess, 27.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 24.9ms
# Speed: 6.1ms preprocess, 24.9ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 50.5ms
# Speed: 2.4ms preprocess, 50.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 3 TWs, 37.3ms
# Speed: 2.5ms preprocess, 37.3ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 28.6ms
# Speed: 3.0ms preprocess, 28.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 TW, 30.3ms
# Speed: 2.6ms preprocess, 30.3ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 29.9ms
# Speed: 2.4ms preprocess, 29.9ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 24.4ms
# Speed: 2.5ms preprocess, 24.4ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 24.6ms
# Speed: 2.2ms preprocess, 24.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 59.7ms
# Speed: 2.7ms preprocess, 59.7ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 22.7ms
# Speed: 2.3ms preprocess, 22.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 47.3ms
# Speed: 3.0ms preprocess, 47.3ms inference, 11.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 28.3ms
# Speed: 2.4ms preprocess, 28.3ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 27.1ms
# Speed: 3.4ms preprocess, 27.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 45.6ms
# Speed: 3.7ms preprocess, 45.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 22.9ms
# Speed: 2.6ms preprocess, 22.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 32.3ms
# Speed: 2.7ms preprocess, 32.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 33.7ms
# Speed: 2.7ms preprocess, 33.7ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 58.1ms
# Speed: 3.3ms preprocess, 58.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 33.9ms
# Speed: 4.6ms preprocess, 33.9ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 22.9ms
# Speed: 2.7ms preprocess, 22.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 RICKs, 32.2ms
# Speed: 2.8ms preprocess, 32.2ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.0ms
# Speed: 2.9ms preprocess, 32.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 41.1ms
# Speed: 3.8ms preprocess, 41.1ms inference, 17.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 30.5ms
# Speed: 5.5ms preprocess, 30.5ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 49.2ms
# Speed: 2.5ms preprocess, 49.2ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 28.2ms
# Speed: 3.8ms preprocess, 28.2ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 LMVs, 1 RICK, 1 TW, 30.4ms
# Speed: 3.5ms preprocess, 30.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.7ms
# Speed: 2.4ms preprocess, 31.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.6ms
# Speed: 2.3ms preprocess, 22.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.9ms
# Speed: 2.4ms preprocess, 28.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 58.1ms
# Speed: 2.9ms preprocess, 58.1ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 24.4ms
# Speed: 2.5ms preprocess, 24.4ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.0ms
# Speed: 2.8ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.5ms
# Speed: 2.9ms preprocess, 22.5ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.7ms
# Speed: 2.8ms preprocess, 24.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.8ms
# Speed: 2.5ms preprocess, 38.8ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.2ms
# Speed: 2.5ms preprocess, 30.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.9ms
# Speed: 2.4ms preprocess, 29.9ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.3ms
# Speed: 2.5ms preprocess, 29.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 34.7ms
# Speed: 2.5ms preprocess, 34.7ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.4ms
# Speed: 2.7ms preprocess, 37.4ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.8ms
# Speed: 2.5ms preprocess, 37.8ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.7ms
# Speed: 2.4ms preprocess, 24.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.3ms
# Speed: 2.3ms preprocess, 28.3ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.0ms
# Speed: 2.4ms preprocess, 26.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 37.5ms
# Speed: 2.5ms preprocess, 37.5ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.6ms
# Speed: 2.2ms preprocess, 24.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.1ms
# Speed: 5.1ms preprocess, 25.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 30.0ms
# Speed: 2.3ms preprocess, 30.0ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 36.8ms
# Speed: 2.8ms preprocess, 36.8ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 1 RICK, 1 TW, 36.9ms
# Speed: 2.3ms preprocess, 36.9ms inference, 16.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.4ms
# Speed: 2.6ms preprocess, 41.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 28.2ms
# Speed: 2.5ms preprocess, 28.2ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 RICK, 24.6ms
# Speed: 2.5ms preprocess, 24.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 5.2ms preprocess, 25.0ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.5ms
# Speed: 2.8ms preprocess, 24.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.1ms
# Speed: 4.2ms preprocess, 23.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 29.6ms
# Speed: 2.4ms preprocess, 29.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 2.9ms preprocess, 25.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 41.0ms
# Speed: 2.5ms preprocess, 41.0ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.6ms
# Speed: 2.5ms preprocess, 24.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.1ms
# Speed: 2.7ms preprocess, 24.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.8ms
# Speed: 4.3ms preprocess, 33.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.3ms
# Speed: 7.5ms preprocess, 28.3ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.6ms
# Speed: 5.1ms preprocess, 43.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 21.3ms
# Speed: 2.2ms preprocess, 21.3ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 40.7ms
# Speed: 2.8ms preprocess, 40.7ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.7ms
# Speed: 3.1ms preprocess, 39.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 25.1ms
# Speed: 3.8ms preprocess, 25.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.3ms
# Speed: 2.8ms preprocess, 45.3ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.4ms
# Speed: 2.2ms preprocess, 29.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.0ms
# Speed: 2.2ms preprocess, 29.0ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.3ms
# Speed: 2.3ms preprocess, 51.3ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.5ms
# Speed: 2.6ms preprocess, 25.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.4ms
# Speed: 2.3ms preprocess, 31.4ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.0ms
# Speed: 2.1ms preprocess, 21.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.1ms
# Speed: 3.2ms preprocess, 48.1ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 29.7ms
# Speed: 2.3ms preprocess, 29.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 23.0ms
# Speed: 2.7ms preprocess, 23.0ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.6ms
# Speed: 2.4ms preprocess, 29.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.2ms
# Speed: 2.7ms preprocess, 33.2ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.0ms
# Speed: 2.6ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 28.9ms
# Speed: 2.7ms preprocess, 28.9ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.5ms
# Speed: 3.8ms preprocess, 37.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 39.0ms
# Speed: 2.8ms preprocess, 39.0ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.4ms
# Speed: 3.3ms preprocess, 23.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.7ms
# Speed: 3.7ms preprocess, 22.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 4.4ms preprocess, 59.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.8ms
# Speed: 3.5ms preprocess, 37.8ms inference, 12.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.3ms
# Speed: 4.5ms preprocess, 23.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 33.9ms
# Speed: 3.2ms preprocess, 33.9ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.7ms
# Speed: 2.6ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.4ms
# Speed: 2.7ms preprocess, 44.4ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 2.6ms preprocess, 40.4ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.7ms
# Speed: 2.5ms preprocess, 23.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.5ms
# Speed: 2.7ms preprocess, 40.5ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.0ms
# Speed: 2.5ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.5ms
# Speed: 2.6ms preprocess, 31.5ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.7ms
# Speed: 2.7ms preprocess, 37.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.2ms
# Speed: 2.3ms preprocess, 26.2ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.6ms
# Speed: 2.7ms preprocess, 29.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.5ms
# Speed: 2.2ms preprocess, 25.5ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.9ms
# Speed: 3.1ms preprocess, 24.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 34.2ms
# Speed: 4.1ms preprocess, 34.2ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.0ms
# Speed: 2.3ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.3ms
# Speed: 2.6ms preprocess, 30.3ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.6ms
# Speed: 2.8ms preprocess, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.1ms
# Speed: 3.4ms preprocess, 28.1ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.2ms
# Speed: 3.0ms preprocess, 36.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.7ms
# Speed: 2.4ms preprocess, 22.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 42.6ms
# Speed: 3.2ms preprocess, 42.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.8ms
# Speed: 2.8ms preprocess, 29.8ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.3ms
# Speed: 2.3ms preprocess, 46.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.4ms
# Speed: 2.7ms preprocess, 26.4ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 34.7ms
# Speed: 4.6ms preprocess, 34.7ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 43.2ms
# Speed: 2.5ms preprocess, 43.2ms inference, 13.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 39.1ms
# Speed: 2.5ms preprocess, 39.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.1ms
# Speed: 5.4ms preprocess, 30.1ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.2ms
# Speed: 4.5ms preprocess, 44.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.5ms
# Speed: 2.6ms preprocess, 38.5ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.4ms
# Speed: 5.4ms preprocess, 24.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.5ms
# Speed: 2.5ms preprocess, 38.5ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 HMVs, 2 LMVs, 29.7ms
# Speed: 2.5ms preprocess, 29.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.0ms
# Speed: 2.4ms preprocess, 41.0ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 25.0ms
# Speed: 3.1ms preprocess, 25.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 30.0ms
# Speed: 2.3ms preprocess, 30.0ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 35.3ms
# Speed: 2.5ms preprocess, 35.3ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 42.8ms
# Speed: 3.2ms preprocess, 42.8ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.9ms
# Speed: 5.3ms preprocess, 24.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 30.7ms
# Speed: 2.9ms preprocess, 30.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 47.1ms
# Speed: 2.5ms preprocess, 47.1ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 50.1ms
# Speed: 2.6ms preprocess, 50.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 46.4ms
# Speed: 3.3ms preprocess, 46.4ms inference, 13.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 28.7ms
# Speed: 3.4ms preprocess, 28.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.9ms
# Speed: 2.5ms preprocess, 23.9ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 37.1ms
# Speed: 2.9ms preprocess, 37.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 37.4ms
# Speed: 3.2ms preprocess, 37.4ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.4ms
# Speed: 6.3ms preprocess, 23.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 59.0ms
# Speed: 5.1ms preprocess, 59.0ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 28.6ms
# Speed: 2.7ms preprocess, 28.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 55.1ms
# Speed: 5.4ms preprocess, 55.1ms inference, 13.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 29.7ms
# Speed: 2.6ms preprocess, 29.7ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.6ms
# Speed: 2.6ms preprocess, 30.6ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.5ms
# Speed: 2.8ms preprocess, 41.5ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 57.9ms
# Speed: 2.5ms preprocess, 57.9ms inference, 13.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 60.7ms
# Speed: 3.4ms preprocess, 60.7ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.0ms
# Speed: 4.5ms preprocess, 41.0ms inference, 14.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.4ms
# Speed: 5.1ms preprocess, 23.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 44.7ms
# Speed: 2.4ms preprocess, 44.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 29.2ms
# Speed: 2.7ms preprocess, 29.2ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 52.7ms
# Speed: 2.7ms preprocess, 52.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 33.2ms
# Speed: 2.5ms preprocess, 33.2ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 32.6ms
# Speed: 3.3ms preprocess, 32.6ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.6ms
# Speed: 2.2ms preprocess, 24.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 44.6ms
# Speed: 2.5ms preprocess, 44.6ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 45.1ms
# Speed: 3.2ms preprocess, 45.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 32.0ms
# Speed: 3.1ms preprocess, 32.0ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 47.8ms
# Speed: 3.8ms preprocess, 47.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 29.3ms
# Speed: 2.6ms preprocess, 29.3ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 32.5ms
# Speed: 4.1ms preprocess, 32.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 36.0ms
# Speed: 5.8ms preprocess, 36.0ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 42.4ms
# Speed: 2.8ms preprocess, 42.4ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.7ms
# Speed: 3.2ms preprocess, 41.7ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 21.7ms
# Speed: 3.1ms preprocess, 21.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 31.2ms
# Speed: 2.6ms preprocess, 31.2ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 26.0ms
# Speed: 5.3ms preprocess, 26.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 57.3ms
# Speed: 2.7ms preprocess, 57.3ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 39.8ms
# Speed: 3.2ms preprocess, 39.8ms inference, 14.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 44.1ms
# Speed: 4.0ms preprocess, 44.1ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 25.2ms
# Speed: 2.2ms preprocess, 25.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 59.2ms
# Speed: 6.4ms preprocess, 59.2ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 42.0ms
# Speed: 2.4ms preprocess, 42.0ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.8ms
# Speed: 2.5ms preprocess, 41.8ms inference, 13.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 49.8ms
# Speed: 3.4ms preprocess, 49.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 38.2ms
# Speed: 3.8ms preprocess, 38.2ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.5ms
# Speed: 2.4ms preprocess, 24.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 34.2ms
# Speed: 2.2ms preprocess, 34.2ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 34.5ms
# Speed: 2.9ms preprocess, 34.5ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.9ms
# Speed: 2.2ms preprocess, 41.9ms inference, 11.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 46.1ms
# Speed: 2.5ms preprocess, 46.1ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 34.0ms
# Speed: 2.7ms preprocess, 34.0ms inference, 13.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 29.2ms
# Speed: 2.7ms preprocess, 29.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 37.6ms
# Speed: 2.7ms preprocess, 37.6ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 30.7ms
# Speed: 2.5ms preprocess, 30.7ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.3ms
# Speed: 3.8ms preprocess, 25.3ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 34.5ms
# Speed: 2.4ms preprocess, 34.5ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.4ms
# Speed: 2.6ms preprocess, 24.4ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 23.1ms
# Speed: 4.8ms preprocess, 23.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.5ms
# Speed: 2.3ms preprocess, 29.5ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.4ms
# Speed: 3.1ms preprocess, 25.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 27.7ms
# Speed: 2.5ms preprocess, 27.7ms inference, 10.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 41.8ms
# Speed: 2.7ms preprocess, 41.8ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 34.7ms
# Speed: 2.8ms preprocess, 34.7ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 31.2ms
# Speed: 2.5ms preprocess, 31.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 30.0ms
# Speed: 2.6ms preprocess, 30.0ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 24.3ms
# Speed: 3.4ms preprocess, 24.3ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 41.4ms
# Speed: 3.2ms preprocess, 41.4ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 30.1ms
# Speed: 4.9ms preprocess, 30.1ms inference, 12.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 36.6ms
# Speed: 2.5ms preprocess, 36.6ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 30.9ms
# Speed: 2.7ms preprocess, 30.9ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 24.7ms
# Speed: 2.6ms preprocess, 24.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 35.9ms
# Speed: 5.0ms preprocess, 35.9ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 38.3ms
# Speed: 3.5ms preprocess, 38.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 58.8ms
# Speed: 4.8ms preprocess, 58.8ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 31.9ms
# Speed: 2.5ms preprocess, 31.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 26.5ms
# Speed: 2.3ms preprocess, 26.5ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 27.2ms
# Speed: 4.4ms preprocess, 27.2ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 35.0ms
# Speed: 2.9ms preprocess, 35.0ms inference, 14.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 HMVs, 1 LMV, 29.9ms
# Speed: 2.6ms preprocess, 29.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 34.1ms
# Speed: 3.3ms preprocess, 34.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 51.5ms
# Speed: 4.7ms preprocess, 51.5ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 40.3ms
# Speed: 2.6ms preprocess, 40.3ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 46.5ms
# Speed: 2.7ms preprocess, 46.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 24.3ms
# Speed: 2.7ms preprocess, 24.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 57.0ms
# Speed: 3.3ms preprocess, 57.0ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.6ms
# Speed: 2.6ms preprocess, 22.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.8ms
# Speed: 3.1ms preprocess, 38.8ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.1ms
# Speed: 2.5ms preprocess, 37.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.1ms
# Speed: 2.7ms preprocess, 28.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.9ms
# Speed: 2.5ms preprocess, 31.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.3ms
# Speed: 3.4ms preprocess, 37.3ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.3ms
# Speed: 2.5ms preprocess, 26.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 LMV, 37.8ms
# Speed: 2.6ms preprocess, 37.8ms inference, 14.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.2ms
# Speed: 5.4ms preprocess, 23.2ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 31.7ms
# Speed: 2.6ms preprocess, 31.7ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 24.4ms
# Speed: 2.4ms preprocess, 24.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 23.9ms
# Speed: 2.5ms preprocess, 23.9ms inference, 13.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 39.7ms
# Speed: 2.3ms preprocess, 39.7ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 22.7ms
# Speed: 2.9ms preprocess, 22.7ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 36.8ms
# Speed: 2.9ms preprocess, 36.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 36.1ms
# Speed: 2.6ms preprocess, 36.1ms inference, 14.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 23.0ms
# Speed: 4.6ms preprocess, 23.0ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 HMV, 1 TW, 28.0ms
# Speed: 3.2ms preprocess, 28.0ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 1 TW, 37.8ms
# Speed: 2.7ms preprocess, 37.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 1 TW, 37.4ms
# Speed: 2.9ms preprocess, 37.4ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 RICK, 1 TW, 30.2ms
# Speed: 2.6ms preprocess, 30.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 35.1ms
# Speed: 3.1ms preprocess, 35.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 56.5ms
# Speed: 2.7ms preprocess, 56.5ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 28.2ms
# Speed: 4.9ms preprocess, 28.2ms inference, 11.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 TW, 24.8ms
# Speed: 3.9ms preprocess, 24.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.5ms
# Speed: 6.7ms preprocess, 30.5ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.5ms
# Speed: 3.1ms preprocess, 23.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.1ms
# Speed: 2.7ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.9ms
# Speed: 2.5ms preprocess, 24.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.5ms
# Speed: 3.9ms preprocess, 40.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.6ms
# Speed: 2.6ms preprocess, 30.6ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.2ms
# Speed: 2.4ms preprocess, 26.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.6ms
# Speed: 2.6ms preprocess, 29.6ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.2ms
# Speed: 3.0ms preprocess, 32.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.5ms
# Speed: 2.3ms preprocess, 28.5ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.5ms
# Speed: 2.8ms preprocess, 43.5ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.9ms
# Speed: 2.2ms preprocess, 30.9ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 27.0ms
# Speed: 2.4ms preprocess, 27.0ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.5ms
# Speed: 2.1ms preprocess, 41.5ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.7ms
# Speed: 2.5ms preprocess, 36.7ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.7ms
# Speed: 2.6ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.6ms
# Speed: 2.6ms preprocess, 29.6ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.6ms
# Speed: 2.5ms preprocess, 25.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 34.0ms
# Speed: 4.8ms preprocess, 34.0ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.7ms
# Speed: 2.6ms preprocess, 30.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.5ms
# Speed: 2.8ms preprocess, 32.5ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.5ms
# Speed: 2.1ms preprocess, 37.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.3ms
# Speed: 2.4ms preprocess, 36.3ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.1ms
# Speed: 2.7ms preprocess, 30.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 35.5ms
# Speed: 2.9ms preprocess, 35.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 28.9ms
# Speed: 2.1ms preprocess, 28.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.5ms
# Speed: 3.1ms preprocess, 32.5ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.7ms
# Speed: 2.2ms preprocess, 33.7ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 36.5ms
# Speed: 4.3ms preprocess, 36.5ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 LMV, 40.5ms
# Speed: 3.2ms preprocess, 40.5ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 33.3ms
# Speed: 2.7ms preprocess, 33.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 37.0ms
# Speed: 2.9ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.0ms
# Speed: 2.2ms preprocess, 40.0ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 38.7ms
# Speed: 5.6ms preprocess, 38.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.2ms
# Speed: 2.4ms preprocess, 45.2ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 6.3ms preprocess, 25.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 41.0ms
# Speed: 2.6ms preprocess, 41.0ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.7ms
# Speed: 4.6ms preprocess, 26.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.8ms
# Speed: 4.4ms preprocess, 32.8ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
